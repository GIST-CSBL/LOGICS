# %%
import sys
sys.path.append('..')

# %%
from logics_pack import global_settings, chemistry, predictor, reward_functions, ahc
from logics_pack import analysis, smiles_vocab, smiles_lstm
import pandas as pd
import numpy as np
import json
import torch

project_paths = global_settings.build_project_paths(project_dir='../')
expset_obj = global_settings.ExperimentSettings(project_paths['EXPERIMENT_SETTINGS_JSON'])

# %% [markdown]
# Perform AHC fine-tuning to build agent generator

# %%
# AHC fine-tuning config
config = global_settings.Object()
config.tokens_path = project_paths['SMILES_TOKENS_PATH']
config.pretrain_setting_path = project_paths['PRETRAIN_SETTING_JSON']
config.pretrained_model_path = project_paths['PROJECT_DIR'] + 'model-prior/prior_e10.ckpt'
config.featurizer = predictor.featurizer
config.predictor_path = project_paths['PROJECT_DIR'] + \
                "model-pik3ca/predictor/pik3ca_rfr_cv%s.pkl"%expset_obj.get_setting("pik3ca-pred-best-cv")
config.max_epoch = 2000  # "epoch" is actually the training batches for reinforcement learning models
config.save_period = 20
config.save_size = 20000
config.save_ckpt_fmt = project_paths['PROJECT_DIR'] + 'model-pik3ca/ahc/pik3ca_ahc_e%d.ckpt'
config.sample_fmt = project_paths['PROJECT_DIR'] + 'model-pik3ca/ahc/pik3ca_ahc_e%d.txt'
config.sigma = 15
config.topk = 0.5  ## AHC
config.nbmax = 100  ## DF2
config.minscore = 0.5  ## DF2
config.dfmode = "linear"  ## DF2
config.rewarding = reward_functions.pAff_to_reward_t2
config.train_batch_size = 128
config.finetune_lr = 0.0003
config.sampling_bs = 256

config.device_name = 'cuda:5'  ####

# %%
# perform fine-tuning
ahc.AHC_training(config)
# Out:
# /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/torch/cuda/__init__.py:145: UserWarning:
# NVIDIA GeForce RTX 3090 with CUDA capability sm_86 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_70.
# If you want to use the NVIDIA GeForce RTX 3090 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))
# --- 0 ---
# ---
# uniq valid count:  118
# avg pkx:  6.855987551099112
# avg filtered scores  0.015686489011443632
# size _scaffolds  1
# top-k reward mean:  0.10765486610391704
# ---
# uniq valid count:  121
# avg pkx:  6.867995350395105
# avg filtered scores  0.020046727496503294
# size _scaffolds  3
# top-k reward mean:  0.09804605950046331
# ---
# uniq valid count:  122
# avg pkx:  6.836356482833382
# avg filtered scores  0.010330820826429169
# size _scaffolds  4
# top-k reward mean:  0.09781661121383697
# ---
# uniq valid count:  119
# avg pkx:  6.954357406708952
# avg filtered scores  0.044714232041536066
# size _scaffolds  7
# top-k reward mean:  0.14437540334134796
# --- 20 ---
# ---
# uniq valid count:  120
# avg pkx:  6.935081905932523
# avg filtered scores  0.03932174487035397
# size _scaffolds  11
# top-k reward mean:  0.12940818965420442
# ---
# uniq valid count:  124
# avg pkx:  6.980177473060254
# avg filtered scores  0.05172374232276404
# size _scaffolds  14
# top-k reward mean:  0.15150972304877525
# ---
# uniq valid count:  126
# avg pkx:  6.996144040195177
# avg filtered scores  0.05658595505786584
# size _scaffolds  17
# top-k reward mean:  0.1625507996746468
# --- 40 ---
# ---
# uniq valid count:  125
# avg pkx:  6.919264165783211
# avg filtered scores  0.0343790738152177
# size _scaffolds  18
# top-k reward mean:  0.13799243236840503
# ---
# uniq valid count:  121
# avg pkx:  6.962770897621211
# avg filtered scores  0.046657238544088056
# size _scaffolds  19
# top-k reward mean:  0.14725550292834594
# ---
# uniq valid count:  125
# avg pkx:  7.002944198457746
# avg filtered scores  0.058922268817149744
# size _scaffolds  19
# top-k reward mean:  0.16077213632221693
# --- 60 ---
# ---
# uniq valid count:  122
# avg pkx:  7.011410702707058
# avg filtered scores  0.060888463560648844
# size _scaffolds  21
# top-k reward mean:  0.1605364394521535
# ---
# uniq valid count:  121
# avg pkx:  7.005383759443283
# avg filtered scores  0.05844813457273162
# size _scaffolds  24
# top-k reward mean:  0.16677080697777866
# ---
# uniq valid count:  121
# avg pkx:  7.082784842652949
# avg filtered scores  0.08132465810090714
# size _scaffolds  33
# top-k reward mean:  0.1972160310126365
# ---
# uniq valid count:  123
# avg pkx:  7.083171634328921
# avg filtered scores  0.08160873657501527
# size _scaffolds  37
# top-k reward mean:  0.19682149626136003
# --- 80 ---
# ---
# uniq valid count:  124
# avg pkx:  7.101184606052761
# avg filtered scores  0.0857935712200516
# size _scaffolds  42
# top-k reward mean:  0.21339355293017226
# ---
# uniq valid count:  119
# avg pkx:  7.053932953443252
# avg filtered scores  0.07261395183577951
# size _scaffolds  58
# top-k reward mean:  0.18096484896844128
# ---
# uniq valid count:  121
# avg pkx:  7.03274974672085
# avg filtered scores  0.06635624849024199
# size _scaffolds  70
# top-k reward mean:  0.18417775904816952
# --- 100 ---
# ---
# uniq valid count:  121
# avg pkx:  7.181061411330397
# avg filtered scores  0.10782451379173132
# size _scaffolds  79
# top-k reward mean:  0.2323637426188124
# ---
# uniq valid count:  123
# avg pkx:  7.2031311443573784
# avg filtered scores  0.11314996099243452
# size _scaffolds  92
# top-k reward mean:  0.26129098645724047
# ---
# uniq valid count:  123
# avg pkx:  7.233048813146131
# avg filtered scores  0.12240928135239762
# size _scaffolds  103
# top-k reward mean:  0.26010884067448486
# --- 120 ---
# ---
# uniq valid count:  123
# avg pkx:  7.1680199717796045
# avg filtered scores  0.10502462661029996
# size _scaffolds  120
# top-k reward mean:  0.23686037275051533
# ---
# uniq valid count:  121
# avg pkx:  7.274023830089408
# avg filtered scores  0.1335506795676308
# size _scaffolds  144
# top-k reward mean:  0.27452728664095594
# ---
# uniq valid count:  123
# avg pkx:  7.217959605239705
# avg filtered scores  0.1174683830468777
# size _scaffolds  159
# top-k reward mean:  0.26743492970906974
# ---
# uniq valid count:  123
# avg pkx:  7.121798198274205
# avg filtered scores  0.091662728067318
# size _scaffolds  175
# top-k reward mean:  0.21795473652919053
# --- 140 ---
# ---
# uniq valid count:  121
# avg pkx:  7.197032690523742
# avg filtered scores  0.1122373371498032
# size _scaffolds  193
# top-k reward mean:  0.25148021569003626
# ---
# uniq valid count:  124
# avg pkx:  7.196250525705856
# avg filtered scores  0.11100296225494424
# size _scaffolds  210
# top-k reward mean:  0.25775525089897733
# ---
# uniq valid count:  122
# avg pkx:  7.399119263864062
# avg filtered scores  0.1682565543270506
# size _scaffolds  237
# top-k reward mean:  0.33742115589831256
# --- 160 ---
# ---
# uniq valid count:  120
# avg pkx:  7.3395923017419555
# avg filtered scores  0.1507220947612836
# size _scaffolds  262
# top-k reward mean:  0.31555040867830664
# ---
# uniq valid count:  125
# avg pkx:  7.370907606712753
# avg filtered scores  0.16092494355348608
# size _scaffolds  288
# top-k reward mean:  0.3219135084025601
# ---
# uniq valid count:  121
# avg pkx:  7.2371222983863905
# avg filtered scores  0.12327564568759151
# size _scaffolds  312
# top-k reward mean:  0.2714972906554787
# --- 180 ---
# ---
# uniq valid count:  123
# avg pkx:  7.40667677379745
# avg filtered scores  0.16986242176025398
# size _scaffolds  334
# top-k reward mean:  0.3373612441013664
# ---
# uniq valid count:  124
# avg pkx:  7.38954294367919
# avg filtered scores  0.16615081576304638
# size _scaffolds  362
# top-k reward mean:  0.3261881247766938
# ---
# uniq valid count:  125
# avg pkx:  7.490835769248821
# avg filtered scores  0.19398967639100587
# size _scaffolds  385
# top-k reward mean:  0.3648869216106381
# ---
# uniq valid count:  126
# avg pkx:  7.235190091431738
# avg filtered scores  0.12326274554153986
# size _scaffolds  408
# top-k reward mean:  0.2749373487862518
# --- 200 ---
# ---
# uniq valid count:  122
# avg pkx:  7.270972968422341
# avg filtered scores  0.13309980639294944
# size _scaffolds  427
# top-k reward mean:  0.2950174314977052
# ---
# uniq valid count:  121
# avg pkx:  7.317118744719433
# avg filtered scores  0.14204513055784052
# size _scaffolds  448
# top-k reward mean:  0.3275269022473781
# ---
# uniq valid count:  119
# avg pkx:  7.572186086648385
# avg filtered scores  0.20936495729013163
# size _scaffolds  478
# top-k reward mean:  0.3952657737721963
# --- 220 ---
# ---
# uniq valid count:  125
# avg pkx:  7.444917117236129
# avg filtered scores  0.1815482650906949
# size _scaffolds  503
# top-k reward mean:  0.3603694634731879
# ---
# uniq valid count:  126
# avg pkx:  7.45961196228864
# avg filtered scores  0.18455424924319408
# size _scaffolds  535
# top-k reward mean:  0.36049117191399493
# ---
# uniq valid count:  122
# avg pkx:  7.398615480166696
# avg filtered scores  0.16719649713196402
# size _scaffolds  557
# top-k reward mean:  0.3484448275119959
# --- 240 ---
# ---
# uniq valid count:  122
# avg pkx:  7.291275949100704
# avg filtered scores  0.1384878786237714
# size _scaffolds  581
# top-k reward mean:  0.3015790710000171
# ---
# uniq valid count:  119
# avg pkx:  7.448321778573521
# avg filtered scores  0.18235640626720456
# size _scaffolds  603
# top-k reward mean:  0.34098321923212127
# ---
# uniq valid count:  124
# avg pkx:  7.459275814463648
# avg filtered scores  0.18547262171191917
# size _scaffolds  625
# top-k reward mean:  0.3581888204192173
# ---
# uniq valid count:  126
# avg pkx:  7.4337132118653075
# avg filtered scores  0.176380031700468
# size _scaffolds  645
# top-k reward mean:  0.35651984185866153
# --- 260 ---
# ---
# uniq valid count:  127
# avg pkx:  7.30534350081592
# avg filtered scores  0.1380153572954418
# size _scaffolds  655
# top-k reward mean:  0.298099502414372
# ---
# uniq valid count:  123
# avg pkx:  7.44536233215083
# avg filtered scores  0.1819281488895339
# size _scaffolds  676
# top-k reward mean:  0.3578349290005903
# ---
# uniq valid count:  120
# avg pkx:  7.518914863264715
# avg filtered scores  0.20143508239214236
# size _scaffolds  699
# top-k reward mean:  0.3616595792025452
# --- 280 ---
# ---
# uniq valid count:  124
# avg pkx:  7.515900496250544
# avg filtered scores  0.20046074905864278
# size _scaffolds  716
# top-k reward mean:  0.38933732684800904
# ---
# uniq valid count:  122
# avg pkx:  7.501542403568548
# avg filtered scores  0.19701525835406566
# size _scaffolds  744
# top-k reward mean:  0.37931816355092535
# ---
# uniq valid count:  127
# avg pkx:  7.437163702319731
# avg filtered scores  0.17835935307775216
# size _scaffolds  764
# top-k reward mean:  0.3675236746090578
# --- 300 ---
# ---
# uniq valid count:  124
# avg pkx:  7.546597442900152
# avg filtered scores  0.20791614185191054
# size _scaffolds  797
# top-k reward mean:  0.40238237796450027
# ---
# uniq valid count:  125
# avg pkx:  7.560064182603854
# avg filtered scores  0.21368629141496115
# size _scaffolds  825
# top-k reward mean:  0.3901952169126659
# ---
# uniq valid count:  125
# avg pkx:  7.520235189315609
# avg filtered scores  0.2010808037955658
# size _scaffolds  860
# top-k reward mean:  0.39133637251558256
# ---
# uniq valid count:  121
# avg pkx:  7.5387270505103485
# avg filtered scores  0.20699886968201647
# size _scaffolds  877
# top-k reward mean:  0.3783748397920328
# --- 320 ---
# ---
# uniq valid count:  125
# avg pkx:  7.404230001671778
# avg filtered scores  0.1662713773744824
# size _scaffolds  905
# top-k reward mean:  0.3440935503524881
# ---
# uniq valid count:  128
# avg pkx:  7.599075630087027
# avg filtered scores  0.2165311370757356
# size _scaffolds  931
# top-k reward mean:  0.39931084365855685
# ---
# uniq valid count:  125
# avg pkx:  7.461086320000328
# avg filtered scores  0.18377495567521293
# size _scaffolds  955
# top-k reward mean:  0.38231620347159806
# --- 340 ---
# ---
# uniq valid count:  126
# avg pkx:  7.490738887145167
# avg filtered scores  0.19410099616885945
# size _scaffolds  982
# top-k reward mean:  0.3783565364698244
# ---
# uniq valid count:  125
# avg pkx:  7.563307065010971
# avg filtered scores  0.2141646473512223
# size _scaffolds  1015
# top-k reward mean:  0.3973793640934745
# ---
# uniq valid count:  121
# avg pkx:  7.445889805673639
# avg filtered scores  0.1817701567510904
# size _scaffolds  1031
# top-k reward mean:  0.35649509143916314
# --- 360 ---
# ---
# uniq valid count:  125
# avg pkx:  7.509999496071919
# avg filtered scores  0.1977253959986393
# size _scaffolds  1056
# top-k reward mean:  0.3898196536633618
# ---
# uniq valid count:  126
# avg pkx:  7.402030424051208
# avg filtered scores  0.16677358225592553
# size _scaffolds  1092
# top-k reward mean:  0.3652486459415003
# ---
# uniq valid count:  125
# avg pkx:  7.589462094305786
# avg filtered scores  0.21898658990395434
# size _scaffolds  1117
# top-k reward mean:  0.41957912997792546
# ---
# uniq valid count:  123
# avg pkx:  7.6089867167412315
# avg filtered scores  0.22384695083655676
# size _scaffolds  1150
# top-k reward mean:  0.40464462677428614
# --- 380 ---
# ---
# uniq valid count:  122
# avg pkx:  7.616487753235498
# avg filtered scores  0.22885074151049795
# size _scaffolds  1186
# top-k reward mean:  0.40811182455677153
# ---
# uniq valid count:  124
# avg pkx:  7.573390543713194
# avg filtered scores  0.21675234530311896
# size _scaffolds  1211
# top-k reward mean:  0.40248312364410344
# ---
# uniq valid count:  124
# avg pkx:  7.540043045248298
# avg filtered scores  0.2065469574051495
# size _scaffolds  1237
# top-k reward mean:  0.39852074651643987
# --- 400 ---
# ---
# uniq valid count:  121
# avg pkx:  7.456607301097125
# avg filtered scores  0.18376153102287887
# size _scaffolds  1272
# top-k reward mean:  0.35551386938370694
# ---
# uniq valid count:  125
# avg pkx:  7.524939093780896
# avg filtered scores  0.19787615360480598
# size _scaffolds  1295
# top-k reward mean:  0.39292385275276553
# ---
# uniq valid count:  126
# avg pkx:  7.660056074858565
# avg filtered scores  0.24020469371537442
# size _scaffolds  1316
# top-k reward mean:  0.4249591674367934
# --- 420 ---
# ---
# uniq valid count:  126
# avg pkx:  7.515380821563373
# avg filtered scores  0.19179364486598144
# size _scaffolds  1338
# top-k reward mean:  0.37659065793546037
# ---
# uniq valid count:  120
# avg pkx:  7.596528785132007
# avg filtered scores  0.2194176499056661
# size _scaffolds  1355
# top-k reward mean:  0.41859900239561587
# ---
# uniq valid count:  120
# avg pkx:  7.752749977565772
# avg filtered scores  0.2505324432731614
# size _scaffolds  1373
# top-k reward mean:  0.43922042737080036
# ---
# uniq valid count:  128
# avg pkx:  7.643507129457618
# avg filtered scores  0.23407268139869725
# size _scaffolds  1405
# top-k reward mean:  0.4403560046658185
# --- 440 ---
# ---
# uniq valid count:  124
# avg pkx:  7.74354561915794
# avg filtered scores  0.25932243698968804
# size _scaffolds  1438
# top-k reward mean:  0.45345073507530553
# ---
# uniq valid count:  125
# avg pkx:  7.574880744154403
# avg filtered scores  0.21608030980140577
# size _scaffolds  1476
# top-k reward mean:  0.4100109582387006
# ---
# uniq valid count:  125
# avg pkx:  7.547963355210614
# avg filtered scores  0.20785186743237588
# size _scaffolds  1502
# top-k reward mean:  0.4108406224402067
# --- 460 ---
# ---
# uniq valid count:  126
# avg pkx:  7.669668044263278
# avg filtered scores  0.23841438227600634
# size _scaffolds  1525
# top-k reward mean:  0.4432292996905326
# ---
# uniq valid count:  126
# avg pkx:  7.571171713035098
# avg filtered scores  0.21588065867949371
# size _scaffolds  1552
# top-k reward mean:  0.40114862587006433
# ---
# uniq valid count:  126
# avg pkx:  7.580100096772398
# avg filtered scores  0.21753692831416646
# size _scaffolds  1579
# top-k reward mean:  0.4261248880945884
# --- 480 ---
# ---
# uniq valid count:  123
# avg pkx:  7.553251502164274
# avg filtered scores  0.2005955316621728
# size _scaffolds  1603
# top-k reward mean:  0.38360369492045643
# ---
# uniq valid count:  124
# avg pkx:  7.6798241839281225
# avg filtered scores  0.2446397514524397
# size _scaffolds  1630
# top-k reward mean:  0.44737466048615726
# ---
# uniq valid count:  126
# avg pkx:  7.7892072561325545
# avg filtered scores  0.26984253510043255
# size _scaffolds  1655
# top-k reward mean:  0.45008855471396686
# ---
# uniq valid count:  125
# avg pkx:  7.582713603074047
# avg filtered scores  0.220417402095135
# size _scaffolds  1678
# top-k reward mean:  0.39884059276258066
# --- 500 ---
# ---
# uniq valid count:  124
# avg pkx:  7.74836386226468
# avg filtered scores  0.2617867317140888
# size _scaffolds  1709
# top-k reward mean:  0.4553579164672616
# ---
# uniq valid count:  119
# avg pkx:  7.606315153784278
# avg filtered scores  0.2190691729924496
# size _scaffolds  1739
# top-k reward mean:  0.4088982770309365
# ---
# uniq valid count:  122
# avg pkx:  7.720932714266309
# avg filtered scores  0.23666192286083676
# size _scaffolds  1769
# top-k reward mean:  0.42330848462177595
# --- 520 ---
# ---
# uniq valid count:  122
# avg pkx:  7.61629305871788
# avg filtered scores  0.2169684472766177
# size _scaffolds  1804
# top-k reward mean:  0.3964193918200446
# ---
# uniq valid count:  126
# avg pkx:  7.6133745937709465
# avg filtered scores  0.2285504392813914
# size _scaffolds  1834
# top-k reward mean:  0.41380608047028233
# ---
# uniq valid count:  125
# avg pkx:  7.506190321749647
# avg filtered scores  0.1961537296357848
# size _scaffolds  1857
# top-k reward mean:  0.40239314987000596
# --- 540 ---
# ---
# uniq valid count:  126
# avg pkx:  7.737279479462451
# avg filtered scores  0.26004635997973613
# size _scaffolds  1887
# top-k reward mean:  0.4468862174021792
# ---
# uniq valid count:  122
# avg pkx:  7.627590374005131
# avg filtered scores  0.2277097856288263
# size _scaffolds  1919
# top-k reward mean:  0.4389476533024817
# ---
# uniq valid count:  126
# avg pkx:  7.793496648034658
# avg filtered scores  0.2766720301933872
# size _scaffolds  1946
# top-k reward mean:  0.46067719158385567
# ---
# uniq valid count:  126
# avg pkx:  7.811097599172908
# avg filtered scores  0.2795439603779496
# size _scaffolds  1974
# top-k reward mean:  0.465156971555405
# --- 560 ---
# ---
# uniq valid count:  125
# avg pkx:  7.737695029119815
# avg filtered scores  0.25801141757472684
# size _scaffolds  2000
# top-k reward mean:  0.43613608126852776
# ---
# uniq valid count:  124
# avg pkx:  7.62894284250875
# avg filtered scores  0.22706404567827215
# size _scaffolds  2029
# top-k reward mean:  0.4126147667334372
# ---
# uniq valid count:  124
# avg pkx:  7.558151682101856
# avg filtered scores  0.20607031463109612
# size _scaffolds  2051
# top-k reward mean:  0.41601957799411476
# --- 580 ---
# ---
# uniq valid count:  124
# avg pkx:  7.684572662860271
# avg filtered scores  0.2468816063601008
# size _scaffolds  2075
# top-k reward mean:  0.4362359398412522
# ---
# uniq valid count:  123
# avg pkx:  7.553288205421611
# avg filtered scores  0.20541637971923438
# size _scaffolds  2096
# top-k reward mean:  0.396953311843933
# ---
# uniq valid count:  119
# avg pkx:  7.641570212872259
# avg filtered scores  0.23301269490392992
# size _scaffolds  2123
# top-k reward mean:  0.42056933038541106
# --- 600 ---
# ---
# uniq valid count:  125
# avg pkx:  7.653843642503294
# avg filtered scores  0.23265185482942172
# size _scaffolds  2154
# top-k reward mean:  0.42362395104250666
# ---
# uniq valid count:  127
# avg pkx:  7.7043595400727165
# avg filtered scores  0.24656346138319893
# size _scaffolds  2187
# top-k reward mean:  0.44720108485683957
# ---
# uniq valid count:  126
# avg pkx:  7.707825687889331
# avg filtered scores  0.25458153387033794
# size _scaffolds  2212
# top-k reward mean:  0.4398762291298619
# ---
# uniq valid count:  126
# avg pkx:  7.747775711512041
# avg filtered scores  0.2583105681418862
# size _scaffolds  2248
# top-k reward mean:  0.45688340521332604
# --- 620 ---
# ---
# uniq valid count:  122
# avg pkx:  7.707835089944392
# avg filtered scores  0.2481947016158467
# size _scaffolds  2281
# top-k reward mean:  0.4470323260518414
# ---
# uniq valid count:  122
# avg pkx:  7.775987063401642
# avg filtered scores  0.27139174767599755
# size _scaffolds  2307
# top-k reward mean:  0.45858640105837206
# ---
# uniq valid count:  122
# avg pkx:  7.649006033185646
# avg filtered scores  0.23526040219716635
# size _scaffolds  2328
# top-k reward mean:  0.4355031906342657
# --- 640 ---
# ---
# uniq valid count:  122
# avg pkx:  7.769946403668254
# avg filtered scores  0.2676614780099762
# size _scaffolds  2359
# top-k reward mean:  0.4555066490227994
# ---
# uniq valid count:  125
# avg pkx:  7.673794707366155
# avg filtered scores  0.23554342357046695
# size _scaffolds  2388
# top-k reward mean:  0.439934367968435
# ---
# uniq valid count:  121
# avg pkx:  7.733272542242122
# avg filtered scores  0.25167830485677056
# size _scaffolds  2416
# top-k reward mean:  0.43669819519572983
# --- 660 ---
# ---
# uniq valid count:  125
# avg pkx:  7.793341156912028
# avg filtered scores  0.270417915461773
# size _scaffolds  2447
# top-k reward mean:  0.4508550601324244
# ---
# uniq valid count:  127
# avg pkx:  7.784431233546244
# avg filtered scores  0.26926120916177415
# size _scaffolds  2472
# top-k reward mean:  0.45781463314444815
# ---
# uniq valid count:  124
# avg pkx:  7.794491913544657
# avg filtered scores  0.2766021284043565
# size _scaffolds  2501
# top-k reward mean:  0.4619140372073748
# ---
# uniq valid count:  126
# avg pkx:  7.81283805300678
# avg filtered scores  0.2749725686833849
# size _scaffolds  2548
# top-k reward mean:  0.47058801758782265
# --- 680 ---
# ---
# uniq valid count:  124
# avg pkx:  7.7042085766919755
# avg filtered scores  0.24568544454046445
# size _scaffolds  2580
# top-k reward mean:  0.4511463026901879
# ---
# uniq valid count:  126
# avg pkx:  7.848883600399583
# avg filtered scores  0.2871069823305207
# size _scaffolds  2609
# top-k reward mean:  0.45413546029260116
# ---
# uniq valid count:  125
# avg pkx:  7.817426362027023
# avg filtered scores  0.2818109744427155
# size _scaffolds  2634
# top-k reward mean:  0.45882128563504293
# --- 700 ---
# ---
# uniq valid count:  125
# avg pkx:  7.8515942894368616
# avg filtered scores  0.289172547483196
# size _scaffolds  2656
# top-k reward mean:  0.4662481729825774
# ---
# uniq valid count:  127
# avg pkx:  7.825096308832912
# avg filtered scores  0.2776377540686463
# size _scaffolds  2685
# top-k reward mean:  0.47009128893211993
# ---
# uniq valid count:  126
# avg pkx:  7.74174025749466
# avg filtered scores  0.2596836457004968
# size _scaffolds  2719
# top-k reward mean:  0.4656675608006681
# --- 720 ---
# ---
# uniq valid count:  126
# avg pkx:  7.748364483471428
# avg filtered scores  0.25296255208388047
# size _scaffolds  2751
# top-k reward mean:  0.46476768330659335
# ---
# uniq valid count:  122
# avg pkx:  7.835070073432363
# avg filtered scores  0.28908765362274264
# size _scaffolds  2772
# top-k reward mean:  0.45702477843050865
# ---
# uniq valid count:  126
# avg pkx:  7.812043392375089
# avg filtered scores  0.2726355611721348
# size _scaffolds  2802
# top-k reward mean:  0.4545333243961542
# ---
# uniq valid count:  124
# avg pkx:  7.81276413818526
# avg filtered scores  0.27771381909666504
# size _scaffolds  2839
# top-k reward mean:  0.4575526500084037
# --- 740 ---
# ---
# uniq valid count:  124
# avg pkx:  7.778174111024174
# avg filtered scores  0.27132208583572537
# size _scaffolds  2867
# top-k reward mean:  0.45722133203282
# ---
# uniq valid count:  123
# avg pkx:  7.964232259144962
# avg filtered scores  0.31022283957858293
# size _scaffolds  2894
# top-k reward mean:  0.46388842387152696
# ---
# uniq valid count:  125
# avg pkx:  7.936974342804366
# avg filtered scores  0.30337310347630536
# size _scaffolds  2916
# top-k reward mean:  0.463626791875442
# --- 760 ---
# ---
# uniq valid count:  124
# avg pkx:  7.762958322692639
# avg filtered scores  0.25928463109554734
# size _scaffolds  2942
# top-k reward mean:  0.45184124768373435
# ---
# uniq valid count:  127
# avg pkx:  7.7623380237149116
# avg filtered scores  0.2633534807785406
# size _scaffolds  2961
# top-k reward mean:  0.4545844192693099
# ---
# uniq valid count:  126
# avg pkx:  7.819100679724344
# avg filtered scores  0.27327178020229
# size _scaffolds  2991
# top-k reward mean:  0.45460926394420464
# --- 780 ---
# ---
# uniq valid count:  121
# avg pkx:  7.841450699930365
# avg filtered scores  0.2886684587503782
# size _scaffolds  3019
# top-k reward mean:  0.4565862184574322
# ---
# uniq valid count:  125
# avg pkx:  7.913876258501001
# avg filtered scores  0.29479609945539414
# size _scaffolds  3049
# top-k reward mean:  0.4640992287884145
# ---
# uniq valid count:  128
# avg pkx:  7.896698952071576
# avg filtered scores  0.3001059671704709
# size _scaffolds  3076
# top-k reward mean:  0.46799434546754787
# ---
# uniq valid count:  128
# avg pkx:  7.717083610824387
# avg filtered scores  0.2457273278315374
# size _scaffolds  3098
# top-k reward mean:  0.4526126307722128
# --- 800 ---
# ---
# uniq valid count:  122
# avg pkx:  7.994956054576292
# avg filtered scores  0.3295308052159467
# size _scaffolds  3124
# top-k reward mean:  0.4682762845625009
# ---
# uniq valid count:  125
# avg pkx:  7.851610217033713
# avg filtered scores  0.28732937188698765
# size _scaffolds  3140
# top-k reward mean:  0.4639442857670875
# ---
# uniq valid count:  124
# avg pkx:  7.801331089391308
# avg filtered scores  0.26972130819317863
# size _scaffolds  3172
# top-k reward mean:  0.461732532132182
# --- 820 ---
# ---
# uniq valid count:  125
# avg pkx:  7.739839638098081
# avg filtered scores  0.2609172032083616
# size _scaffolds  3188
# top-k reward mean:  0.4573226863207532
# ---
# uniq valid count:  125
# avg pkx:  7.795367300168142
# avg filtered scores  0.2703087658479801
# size _scaffolds  3220
# top-k reward mean:  0.45889209218630395
# ---
# uniq valid count:  123
# avg pkx:  7.856788338338029
# avg filtered scores  0.28931583331602057
# size _scaffolds  3249
# top-k reward mean:  0.46301035560367715
# --- 840 ---
# ---
# uniq valid count:  126
# avg pkx:  7.825929060403066
# avg filtered scores  0.2813014674576047
# size _scaffolds  3276
# top-k reward mean:  0.4589008903572934
# ---
# uniq valid count:  122
# avg pkx:  7.969186251468299
# avg filtered scores  0.3147978473494059
# size _scaffolds  3307
# top-k reward mean:  0.4686131669978705
# ---
# uniq valid count:  126
# avg pkx:  7.951451975902568
# avg filtered scores  0.31511213821636624
# size _scaffolds  3335
# top-k reward mean:  0.472327799353128
# ---
# uniq valid count:  125
# avg pkx:  7.831992707713503
# avg filtered scores  0.2811213425145029
# size _scaffolds  3362
# top-k reward mean:  0.45685621018474976
# --- 860 ---
# ---
# uniq valid count:  123
# avg pkx:  7.916665079799994
# avg filtered scores  0.3062439198559231
# size _scaffolds  3379
# top-k reward mean:  0.4628689768076483
# ---
# uniq valid count:  128
# avg pkx:  7.956921580311609
# avg filtered scores  0.3170467310681027
# size _scaffolds  3408
# top-k reward mean:  0.4627786647452265
# ---
# uniq valid count:  123
# avg pkx:  7.863507835479988
# avg filtered scores  0.27866432776946454
# size _scaffolds  3428
# top-k reward mean:  0.4612647456823609
# --- 880 ---
# ---
# uniq valid count:  123
# avg pkx:  7.847730939858783
# avg filtered scores  0.28278264222082333
# size _scaffolds  3462
# top-k reward mean:  0.46349241904285826
# ---
# uniq valid count:  125
# avg pkx:  7.810193438267164
# avg filtered scores  0.2711643659884395
# size _scaffolds  3490
# top-k reward mean:  0.4624862724861358
# ---
# uniq valid count:  128
# avg pkx:  7.8665314412289895
# avg filtered scores  0.28762920872166403
# size _scaffolds  3522
# top-k reward mean:  0.4637228435146246
# --- 900 ---
# ---
# uniq valid count:  123
# avg pkx:  7.904290431858085
# avg filtered scores  0.3070849607469595
# size _scaffolds  3539
# top-k reward mean:  0.46269125523630394
# ---
# uniq valid count:  123
# avg pkx:  7.754594580696905
# avg filtered scores  0.26182278802383935
# size _scaffolds  3559
# top-k reward mean:  0.46198056599207976
# ---
# uniq valid count:  125
# avg pkx:  7.862237312842254
# avg filtered scores  0.28579949676583544
# size _scaffolds  3581
# top-k reward mean:  0.4708055226221912
# ---
# uniq valid count:  126
# avg pkx:  7.95074982781215
# avg filtered scores  0.30381943226177893
# size _scaffolds  3607
# top-k reward mean:  0.46389571789464257
# --- 920 ---
# ---
# uniq valid count:  125
# avg pkx:  7.88007237084902
# avg filtered scores  0.29376746756502203
# size _scaffolds  3631
# top-k reward mean:  0.4733934058694441
# ---
# uniq valid count:  124
# avg pkx:  8.026021020646725
# avg filtered scores  0.33396816989248945
# size _scaffolds  3650
# top-k reward mean:  0.4696826221327537
# ---
# uniq valid count:  127
# avg pkx:  7.87376019814195
# avg filtered scores  0.29265424545879043
# size _scaffolds  3683
# top-k reward mean:  0.4688478881459617
# --- 940 ---
# ---
# uniq valid count:  127
# avg pkx:  7.868115457666291
# avg filtered scores  0.28240921276612385
# size _scaffolds  3706
# top-k reward mean:  0.46565220473383745
# ---
# uniq valid count:  124
# avg pkx:  7.804610655508649
# avg filtered scores  0.27891395413239306
# size _scaffolds  3742
# top-k reward mean:  0.4648183333330236
# ---
# uniq valid count:  125
# avg pkx:  7.886116817123704
# avg filtered scores  0.29201172630057753
# size _scaffolds  3766
# top-k reward mean:  0.4705338805191646
# --- 960 ---
# ---
# uniq valid count:  124
# avg pkx:  7.954084246517507
# avg filtered scores  0.3085601914902076
# size _scaffolds  3792
# top-k reward mean:  0.47068896488080936
# ---
# uniq valid count:  126
# avg pkx:  7.859416456880588
# avg filtered scores  0.2835962686053291
# size _scaffolds  3809
# top-k reward mean:  0.4616810257918733
# ---
# uniq valid count:  122
# avg pkx:  7.8191598013278165
# avg filtered scores  0.27810582103888914
# size _scaffolds  3844
# top-k reward mean:  0.461876955985328
# ---
# uniq valid count:  125
# avg pkx:  7.862767407511229
# avg filtered scores  0.2888435517461573
# size _scaffolds  3864
# top-k reward mean:  0.46979968833538854
# --- 980 ---
# ---
# uniq valid count:  125
# avg pkx:  7.78532989438702
# avg filtered scores  0.27349785768987184
# size _scaffolds  3889
# top-k reward mean:  0.4556916674036565
# ---
# uniq valid count:  124
# avg pkx:  7.9999103780063265
# avg filtered scores  0.32327124089439624
# size _scaffolds  3926
# top-k reward mean:  0.4715899258685182
# ---
# uniq valid count:  123
# avg pkx:  7.962215222334164
# avg filtered scores  0.32197245272551944
# size _scaffolds  3951
# top-k reward mean:  0.46753664578755794
# --- 1000 ---
# ---
# uniq valid count:  122
# avg pkx:  8.045163849173456
# avg filtered scores  0.33217132455402426
# size _scaffolds  3985
# top-k reward mean:  0.4654304777355627
# ---
# uniq valid count:  120
# avg pkx:  7.9711711103071075
# avg filtered scores  0.3078898652592848
# size _scaffolds  4017
# top-k reward mean:  0.4707835810353186
# ---
# uniq valid count:  123
# avg pkx:  8.017055070542515
# avg filtered scores  0.32684962249716554
# size _scaffolds  4038
# top-k reward mean:  0.47317572199835756
# --- 1020 ---
# ---
# uniq valid count:  124
# avg pkx:  7.894315403613594
# avg filtered scores  0.29464799996563384
# size _scaffolds  4060
# top-k reward mean:  0.46837813328496525
# ---
# uniq valid count:  124
# avg pkx:  7.9902314393620655
# avg filtered scores  0.3133308082782659
# size _scaffolds  4085
# top-k reward mean:  0.4655866886969846
# ---
# uniq valid count:  124
# avg pkx:  7.809826339554721
# avg filtered scores  0.27887654757726504
# size _scaffolds  4114
# top-k reward mean:  0.46565723938123726
# ---
# uniq valid count:  124
# avg pkx:  7.972389677358383
# avg filtered scores  0.321508709491692
# size _scaffolds  4137
# top-k reward mean:  0.4682289007951995
# --- 1040 ---
# ---
# uniq valid count:  126
# avg pkx:  7.888640077309268
# avg filtered scores  0.2964487021655323
# size _scaffolds  4164
# top-k reward mean:  0.46795564538891377
# ---
# uniq valid count:  125
# avg pkx:  7.857859623030959
# avg filtered scores  0.28200551393016693
# size _scaffolds  4185
# top-k reward mean:  0.46491559070738697
# ---
# uniq valid count:  126
# avg pkx:  7.947861653586558
# avg filtered scores  0.31407784439895275
# size _scaffolds  4207
# top-k reward mean:  0.466954509913457
# --- 1060 ---
# ---
# uniq valid count:  124
# avg pkx:  7.942070550407731
# avg filtered scores  0.31305059385673284
# size _scaffolds  4227
# top-k reward mean:  0.46325087837104517
# ---
# uniq valid count:  127
# avg pkx:  7.867566000154499
# avg filtered scores  0.2929090241904801
# size _scaffolds  4253
# top-k reward mean:  0.46339564788640797
# ---
# uniq valid count:  125
# avg pkx:  7.958822933992933
# avg filtered scores  0.30656633092979707
# size _scaffolds  4276
# top-k reward mean:  0.47335470574284055
# --- 1080 ---
# ---
# uniq valid count:  123
# avg pkx:  8.037309806998634
# avg filtered scores  0.3366970411592831
# size _scaffolds  4299
# top-k reward mean:  0.4764850820586587
# ---
# uniq valid count:  124
# avg pkx:  7.965173740717283
# avg filtered scores  0.3178991656717806
# size _scaffolds  4325
# top-k reward mean:  0.46684967175786096
# ---
# uniq valid count:  125
# avg pkx:  8.038720138457162
# avg filtered scores  0.34386349606297684
# size _scaffolds  4355
# top-k reward mean:  0.47271439974322804
# ---
# uniq valid count:  124
# avg pkx:  8.023581011967089
# avg filtered scores  0.33173693932390325
# size _scaffolds  4383
# top-k reward mean:  0.4625110795970465
# --- 1100 ---
# ---
# uniq valid count:  124
# avg pkx:  7.976428946968633
# avg filtered scores  0.3104843110885642
# size _scaffolds  4416
# top-k reward mean:  0.46856810726726295
# ---
# uniq valid count:  126
# avg pkx:  8.06054018430288
# avg filtered scores  0.33968223312943424
# size _scaffolds  4443
# top-k reward mean:  0.47338950751938164
# ---
# uniq valid count:  127
# avg pkx:  8.081269437868453
# avg filtered scores  0.33419970784763414
# size _scaffolds  4477
# top-k reward mean:  0.47352070586156797
# --- 1120 ---
# ---
# uniq valid count:  126
# avg pkx:  7.991282186663046
# avg filtered scores  0.3240539482729559
# size _scaffolds  4506
# top-k reward mean:  0.4719199848436331
# ---
# uniq valid count:  126
# avg pkx:  8.089995134852465
# avg filtered scores  0.3475030319781679
# size _scaffolds  4533
# top-k reward mean:  0.4768813441657413
# ---
# uniq valid count:  128
# avg pkx:  8.092515985008877
# avg filtered scores  0.34933500155968156
# size _scaffolds  4561
# top-k reward mean:  0.4697696448860106
# --- 1140 ---
# ---
# uniq valid count:  125
# avg pkx:  7.955262860140048
# avg filtered scores  0.30947865439343475
# size _scaffolds  4595
# top-k reward mean:  0.47608822509790216
# ---
# uniq valid count:  125
# avg pkx:  7.938848096616621
# avg filtered scores  0.3019152332505597
# size _scaffolds  4617
# top-k reward mean:  0.4710818900791415
# ---
# uniq valid count:  127
# avg pkx:  7.879182955185619
# avg filtered scores  0.2958778363539598
# size _scaffolds  4647
# top-k reward mean:  0.46556590121014174
# ---
# uniq valid count:  123
# avg pkx:  7.954796077707504
# avg filtered scores  0.3095845854786501
# size _scaffolds  4671
# top-k reward mean:  0.4641430489025497
# --- 1160 ---
# ---
# uniq valid count:  121
# avg pkx:  7.966130647908016
# avg filtered scores  0.31758585386398475
# size _scaffolds  4714
# top-k reward mean:  0.4683794998532315
# ---
# uniq valid count:  123
# avg pkx:  7.962898577322508
# avg filtered scores  0.3111254565112684
# size _scaffolds  4741
# top-k reward mean:  0.47037630748340975
# ---
# uniq valid count:  124
# avg pkx:  7.9651713785842535
# avg filtered scores  0.3038612146137094
# size _scaffolds  4767
# top-k reward mean:  0.46632119054218235
# --- 1180 ---
# ---
# uniq valid count:  121
# avg pkx:  7.992994689233988
# avg filtered scores  0.31549609133063483
# size _scaffolds  4796
# top-k reward mean:  0.47099160187434264
# ---
# uniq valid count:  125
# avg pkx:  7.952794751408871
# avg filtered scores  0.303025964534082
# size _scaffolds  4826
# top-k reward mean:  0.4707379940205445
# ---
# uniq valid count:  126
# avg pkx:  7.990517974826158
# avg filtered scores  0.3288251005728561
# size _scaffolds  4857
# top-k reward mean:  0.47094935782870895
# --- 1200 ---
# ---
# uniq valid count:  126
# avg pkx:  8.015438737409747
# avg filtered scores  0.3316541360514175
# size _scaffolds  4887
# top-k reward mean:  0.47780158912547055
# ---
# uniq valid count:  126
# avg pkx:  8.0962115005895
# avg filtered scores  0.3447631457195523
# size _scaffolds  4916
# top-k reward mean:  0.4704762489662887
# ---
# uniq valid count:  125
# avg pkx:  8.030634583430196
# avg filtered scores  0.33447456414346344
# size _scaffolds  4951
# top-k reward mean:  0.47735291740392366
# ---
# uniq valid count:  126
# avg pkx:  7.9932334600646175
# avg filtered scores  0.3176125021696383
# size _scaffolds  4971
# top-k reward mean:  0.47096809228955705
# --- 1220 ---
# ---
# uniq valid count:  127
# avg pkx:  8.090955346189883
# avg filtered scores  0.35594878448993783
# size _scaffolds  4991
# top-k reward mean:  0.47323551215790527
# ---
# uniq valid count:  127
# avg pkx:  8.019610394363088
# avg filtered scores  0.3318933307771912
# size _scaffolds  5018
# top-k reward mean:  0.47874696929381744
# ---
# uniq valid count:  125
# avg pkx:  7.9601075759536855
# avg filtered scores  0.3118120486220288
# size _scaffolds  5047
# top-k reward mean:  0.4650098075355014
# --- 1240 ---
# ---
# uniq valid count:  127
# avg pkx:  8.083204555255131
# avg filtered scores  0.3512470954288843
# size _scaffolds  5070
# top-k reward mean:  0.47478747733641324
# ---
# uniq valid count:  126
# avg pkx:  7.893590369415044
# avg filtered scores  0.29015549096044085
# size _scaffolds  5103
# top-k reward mean:  0.4721484240265748
# ---
# uniq valid count:  125
# avg pkx:  7.982001625608754
# avg filtered scores  0.32224978042305047
# size _scaffolds  5136
# top-k reward mean:  0.4694856663086504
# --- 1260 ---
# ---
# uniq valid count:  127
# avg pkx:  7.997623088397712
# avg filtered scores  0.3236311807383455
# size _scaffolds  5163
# top-k reward mean:  0.4719200375018034
# ---
# uniq valid count:  126
# avg pkx:  7.9124083864198544
# avg filtered scores  0.301914094595957
# size _scaffolds  5195
# top-k reward mean:  0.469652091373457
# ---
# uniq valid count:  126
# avg pkx:  8.062890257885538
# avg filtered scores  0.343679080904568
# size _scaffolds  5235
# top-k reward mean:  0.4711674818524249
# ---
# uniq valid count:  123
# avg pkx:  8.01143793698146
# avg filtered scores  0.32157768751055926
# size _scaffolds  5258
# top-k reward mean:  0.4664937654467662
# --- 1280 ---
# ---
# uniq valid count:  123
# avg pkx:  7.998597078964728
# avg filtered scores  0.32545621289160687
# size _scaffolds  5285
# top-k reward mean:  0.4793242860986964
# ---
# uniq valid count:  125
# avg pkx:  7.99982319272201
# avg filtered scores  0.3318078345255182
# size _scaffolds  5309
# top-k reward mean:  0.4704034309337125
# ---
# uniq valid count:  126
# avg pkx:  8.12020994287719
# avg filtered scores  0.3535712434732602
# size _scaffolds  5341
# top-k reward mean:  0.47784074279116595
# --- 1300 ---
# ---
# uniq valid count:  125
# avg pkx:  7.934730940308292
# avg filtered scores  0.28316183063163863
# size _scaffolds  5372
# top-k reward mean:  0.46653015550559607
# ---
# uniq valid count:  121
# avg pkx:  7.945570860112748
# avg filtered scores  0.30288717602016796
# size _scaffolds  5397
# top-k reward mean:  0.46738130616100537
# ---
# uniq valid count:  127
# avg pkx:  7.98937470620484
# avg filtered scores  0.3290347382836601
# size _scaffolds  5428
# top-k reward mean:  0.4742721030947556
# --- 1320 ---
# ---
# uniq valid count:  126
# avg pkx:  7.928975909951444
# avg filtered scores  0.3092357152805324
# size _scaffolds  5462
# top-k reward mean:  0.46462736824069223
# ---
# uniq valid count:  126
# avg pkx:  7.9590423468090306
# avg filtered scores  0.3145828839024443
# size _scaffolds  5492
# top-k reward mean:  0.4710501609663139
# ---
# uniq valid count:  127
# avg pkx:  7.873811572773312
# avg filtered scores  0.2835747479556072
# size _scaffolds  5522
# top-k reward mean:  0.46187735645156325
# ---
# uniq valid count:  126
# avg pkx:  8.084199043510333
# avg filtered scores  0.3374655572899396
# size _scaffolds  5545
# top-k reward mean:  0.47553307794228306
# --- 1340 ---
# ---
# uniq valid count:  125
# avg pkx:  7.805128945524381
# avg filtered scores  0.2706034020303337
# size _scaffolds  5562
# top-k reward mean:  0.46071571546008605
# ---
# uniq valid count:  126
# avg pkx:  7.950255174814794
# avg filtered scores  0.30841093497024064
# size _scaffolds  5584
# top-k reward mean:  0.4731379812589416
# ---
# uniq valid count:  123
# avg pkx:  7.880385182377353
# avg filtered scores  0.2935468514180857
# size _scaffolds  5624
# top-k reward mean:  0.4709840125293908
# --- 1360 ---
# ---
# uniq valid count:  124
# avg pkx:  7.9408482054010445
# avg filtered scores  0.3118365398670137
# size _scaffolds  5654
# top-k reward mean:  0.4633948568488774
# ---
# uniq valid count:  124
# avg pkx:  8.021905705419298
# avg filtered scores  0.3053642379001034
# size _scaffolds  5674
# top-k reward mean:  0.4707182362830129
# ---
# uniq valid count:  126
# avg pkx:  8.0983386800611
# avg filtered scores  0.3524650617806962
# size _scaffolds  5702
# top-k reward mean:  0.47449338896542925
# --- 1380 ---
# ---
# uniq valid count:  122
# avg pkx:  7.988653121538481
# avg filtered scores  0.32751629496291235
# size _scaffolds  5730
# top-k reward mean:  0.4712049197753754
# ---
# uniq valid count:  126
# avg pkx:  7.956330367940258
# avg filtered scores  0.3053235305057337
# size _scaffolds  5763
# top-k reward mean:  0.47608474876882667
# ---
# uniq valid count:  125
# avg pkx:  7.904308530710627
# avg filtered scores  0.30033811217213136
# size _scaffolds  5794
# top-k reward mean:  0.46432058436334633
# ---
# uniq valid count:  126
# avg pkx:  7.998843357638646
# avg filtered scores  0.32275014320886586
# size _scaffolds  5823
# top-k reward mean:  0.4681540667055202
# --- 1400 ---
# ---
# uniq valid count:  124
# avg pkx:  7.994381207670657
# avg filtered scores  0.3268587080181408
# size _scaffolds  5853
# top-k reward mean:  0.4724348494814823
# ---
# uniq valid count:  125
# avg pkx:  7.919301704699261
# avg filtered scores  0.3028605608097368
# size _scaffolds  5876
# top-k reward mean:  0.46573984838677157
# ---
# uniq valid count:  126
# avg pkx:  7.906875105523664
# avg filtered scores  0.3047240351848024
# size _scaffolds  5908
# top-k reward mean:  0.46931990788987854
# --- 1420 ---
# ---
# uniq valid count:  124
# avg pkx:  8.051182506302323
# avg filtered scores  0.32803669647841205
# size _scaffolds  5937
# top-k reward mean:  0.47324571946132793
# ---
# uniq valid count:  125
# avg pkx:  7.882488894481114
# avg filtered scores  0.29482146050885233
# size _scaffolds  5962
# top-k reward mean:  0.46084748257173036
# ---
# uniq valid count:  126
# avg pkx:  8.093443373082419
# avg filtered scores  0.34126434537920725
# size _scaffolds  5998
# top-k reward mean:  0.47145768841885605
# --- 1440 ---
# ---
# uniq valid count:  128
# avg pkx:  8.029138738980334
# avg filtered scores  0.31702004831887537
# size _scaffolds  6035
# top-k reward mean:  0.4653756925026198
# ---
# uniq valid count:  125
# avg pkx:  8.1230415808276
# avg filtered scores  0.3547133716395389
# size _scaffolds  6055
# top-k reward mean:  0.48164444550843927
# ---
# uniq valid count:  126
# avg pkx:  7.925479766389744
# avg filtered scores  0.2924898505457621
# size _scaffolds  6079
# top-k reward mean:  0.45984867375340854
# ---
# uniq valid count:  123
# avg pkx:  7.9176532602802565
# avg filtered scores  0.30589858407073656
# size _scaffolds  6112
# top-k reward mean:  0.4675868213988724
# --- 1460 ---
# ---
# uniq valid count:  124
# avg pkx:  7.999503026628771
# avg filtered scores  0.31020514681727623
# size _scaffolds  6140
# top-k reward mean:  0.47527920301771653
# ---
# uniq valid count:  126
# avg pkx:  8.02389727060555
# avg filtered scores  0.3302995152112206
# size _scaffolds  6165
# top-k reward mean:  0.47568237432376737
# ---
# uniq valid count:  124
# avg pkx:  7.997168855704053
# avg filtered scores  0.3249199241352678
# size _scaffolds  6199
# top-k reward mean:  0.4742657562096487
# --- 1480 ---
# ---
# uniq valid count:  123
# avg pkx:  8.15388507755384
# avg filtered scores  0.3451527822805783
# size _scaffolds  6222
# top-k reward mean:  0.4771232823401871
# ---
# uniq valid count:  128
# avg pkx:  8.086829673340592
# avg filtered scores  0.3213908886768151
# size _scaffolds  6246
# top-k reward mean:  0.4720181398047768
# ---
# uniq valid count:  125
# avg pkx:  7.974230482713448
# avg filtered scores  0.31938024239308715
# size _scaffolds  6272
# top-k reward mean:  0.46982574075817024
# --- 1500 ---
# ---
# uniq valid count:  127
# avg pkx:  7.900592019355521
# avg filtered scores  0.2958963144185038
# size _scaffolds  6298
# top-k reward mean:  0.46868804440846357
# ---
# uniq valid count:  124
# avg pkx:  8.073583185214448
# avg filtered scores  0.3491482088241368
# size _scaffolds  6324
# top-k reward mean:  0.4749498045574555
# ---
# uniq valid count:  127
# avg pkx:  8.028441205962332
# avg filtered scores  0.3278946952253513
# size _scaffolds  6346
# top-k reward mean:  0.4740121746987217
# ---
# uniq valid count:  126
# avg pkx:  7.999739507471088
# avg filtered scores  0.3236567833919175
# size _scaffolds  6382
# top-k reward mean:  0.47395461856872056
# --- 1520 ---
# ---
# uniq valid count:  128
# avg pkx:  8.009222726429593
# avg filtered scores  0.3169903425571743
# size _scaffolds  6409
# top-k reward mean:  0.47766876751855447
# ---
# uniq valid count:  125
# avg pkx:  7.99733847359489
# avg filtered scores  0.314599632926211
# size _scaffolds  6426
# top-k reward mean:  0.47097746866517676
# ---
# uniq valid count:  126
# avg pkx:  8.013481935314795
# avg filtered scores  0.3178342686803228
# size _scaffolds  6463
# top-k reward mean:  0.46753472817480274
# --- 1540 ---
# ---
# uniq valid count:  125
# avg pkx:  8.0532970851299
# avg filtered scores  0.3389913718499941
# size _scaffolds  6483
# top-k reward mean:  0.47610883169287027
# ---
# uniq valid count:  126
# avg pkx:  8.057403702489825
# avg filtered scores  0.3376438493656346
# size _scaffolds  6505
# top-k reward mean:  0.46919517531916155
# ---
# uniq valid count:  126
# avg pkx:  7.906507958280849
# avg filtered scores  0.3016134372349057
# size _scaffolds  6535
# top-k reward mean:  0.4646925682021604
# --- 1560 ---
# ---
# uniq valid count:  126
# avg pkx:  8.134213119684228
# avg filtered scores  0.3572007495878772
# size _scaffolds  6562
# top-k reward mean:  0.48066984255345513
# ---
# uniq valid count:  125
# avg pkx:  8.021220846774696
# avg filtered scores  0.32874674358446876
# size _scaffolds  6581
# top-k reward mean:  0.4774644504349004
# ---
# uniq valid count:  127
# avg pkx:  7.9264531800254066
# avg filtered scores  0.30719374170763947
# size _scaffolds  6611
# top-k reward mean:  0.4757815011931168
# ---
# uniq valid count:  123
# avg pkx:  8.055288523251459
# avg filtered scores  0.3329081787115059
# size _scaffolds  6642
# top-k reward mean:  0.4731646044558854
# --- 1580 ---
# ---
# uniq valid count:  124
# avg pkx:  7.997352034852897
# avg filtered scores  0.3324353203088886
# size _scaffolds  6669
# top-k reward mean:  0.46935832660468685
# ---
# uniq valid count:  123
# avg pkx:  8.02816268740946
# avg filtered scores  0.3196589396693468
# size _scaffolds  6699
# top-k reward mean:  0.47096517056562065
# ---
# uniq valid count:  126
# avg pkx:  7.970538174447697
# avg filtered scores  0.31091008260047537
# size _scaffolds  6734
# top-k reward mean:  0.48236082563744215
# --- 1600 ---
# ---
# uniq valid count:  126
# avg pkx:  8.0850244097198
# avg filtered scores  0.3514312236185733
# size _scaffolds  6756
# top-k reward mean:  0.4757579053238615
# ---
# uniq valid count:  126
# avg pkx:  7.978173018446626
# avg filtered scores  0.3018077771013106
# size _scaffolds  6791
# top-k reward mean:  0.47063238234634874
# ---
# uniq valid count:  124
# avg pkx:  8.133811954023848
# avg filtered scores  0.342324758156521
# size _scaffolds  6818
# top-k reward mean:  0.4764032803670916
# --- 1620 ---
# ---
# uniq valid count:  124
# avg pkx:  8.09359548083155
# avg filtered scores  0.3542665622533094
# size _scaffolds  6855
# top-k reward mean:  0.4748679128502631
# ---
# uniq valid count:  124
# avg pkx:  8.043877709212008
# avg filtered scores  0.33966994908266346
# size _scaffolds  6885
# top-k reward mean:  0.4835949335016135
# ---
# uniq valid count:  128
# avg pkx:  8.032470320328272
# avg filtered scores  0.3329558214843932
# size _scaffolds  6922
# top-k reward mean:  0.4741099448247059
# ---
# uniq valid count:  124
# avg pkx:  8.045273733683548
# avg filtered scores  0.34140450345510476
# size _scaffolds  6967
# top-k reward mean:  0.47940042695467766
# --- 1640 ---
# ---
# uniq valid count:  125
# avg pkx:  8.034549728977135
# avg filtered scores  0.3245883057954788
# size _scaffolds  7000
# top-k reward mean:  0.4738142607381082
# ---
# uniq valid count:  127
# avg pkx:  8.106314334642985
# avg filtered scores  0.34593659648691316
# size _scaffolds  7025
# top-k reward mean:  0.47414481864789304
# ---
# uniq valid count:  128
# avg pkx:  8.007641076338132
# avg filtered scores  0.31750240125536083
# size _scaffolds  7058
# top-k reward mean:  0.47708654230146597
# --- 1660 ---
# ---
# uniq valid count:  125
# avg pkx:  8.037410643467252
# avg filtered scores  0.32218545893014905
# size _scaffolds  7090
# top-k reward mean:  0.4773290290493714
# ---
# uniq valid count:  126
# avg pkx:  7.998160863757444
# avg filtered scores  0.3249025676106727
# size _scaffolds  7123
# top-k reward mean:  0.4672894088773447
# ---
# uniq valid count:  125
# avg pkx:  8.04156695884776
# avg filtered scores  0.3299769973753208
# size _scaffolds  7152
# top-k reward mean:  0.47358955289815546
# --- 1680 ---
# ---
# uniq valid count:  125
# avg pkx:  7.8855743391329485
# avg filtered scores  0.2852648187391403
# size _scaffolds  7171
# top-k reward mean:  0.468138617061718
# ---
# uniq valid count:  125
# avg pkx:  8.074811754100798
# avg filtered scores  0.34121051007826414
# size _scaffolds  7198
# top-k reward mean:  0.47713138418776607
# ---
# uniq valid count:  128
# avg pkx:  8.030247735494061
# avg filtered scores  0.3222868450342312
# size _scaffolds  7231
# top-k reward mean:  0.47890557658461463
# ---
# uniq valid count:  124
# avg pkx:  8.104798983812476
# avg filtered scores  0.3500990209945319
# size _scaffolds  7260
# top-k reward mean:  0.4785552490564523
# --- 1700 ---
# ---
# uniq valid count:  127
# avg pkx:  8.021291680979747
# avg filtered scores  0.31982869354877974
# size _scaffolds  7286
# top-k reward mean:  0.47450499537348123
# ---
# uniq valid count:  122
# avg pkx:  8.046782036331932
# avg filtered scores  0.3179238220634452
# size _scaffolds  7316
# top-k reward mean:  0.47509248163150997
# ---
# uniq valid count:  124
# avg pkx:  7.988040482678096
# avg filtered scores  0.3235429098337243
# size _scaffolds  7342
# top-k reward mean:  0.47444289025088027
# --- 1720 ---
# ---
# uniq valid count:  126
# avg pkx:  7.917531821607667
# avg filtered scores  0.29929015666798897
# size _scaffolds  7373
# top-k reward mean:  0.4658743653484918
# ---
# uniq valid count:  122
# avg pkx:  8.121371803303541
# avg filtered scores  0.34259830692983584
# size _scaffolds  7406
# top-k reward mean:  0.47865389094425137
# ---
# uniq valid count:  125
# avg pkx:  8.03880587055858
# avg filtered scores  0.30787811155374284
# size _scaffolds  7439
# top-k reward mean:  0.4749647729684683
# --- 1740 ---
# ---
# uniq valid count:  125
# avg pkx:  7.972082969402034
# avg filtered scores  0.31507645478985324
# size _scaffolds  7464
# top-k reward mean:  0.46996968378557535
# ---
# uniq valid count:  127
# avg pkx:  7.943711452027886
# avg filtered scores  0.30731965678557116
# size _scaffolds  7491
# top-k reward mean:  0.47594475515949863
# ---
# uniq valid count:  125
# avg pkx:  8.056589872949239
# avg filtered scores  0.32413423541206327
# size _scaffolds  7523
# top-k reward mean:  0.4756857869690708
# ---
# uniq valid count:  126
# avg pkx:  8.094556653438994
# avg filtered scores  0.3430260213052475
# size _scaffolds  7559
# top-k reward mean:  0.479978997906113
# --- 1760 ---
# ---
# uniq valid count:  126
# avg pkx:  7.989337590233036
# avg filtered scores  0.3184049432811878
# size _scaffolds  7591
# top-k reward mean:  0.47831144998443614
# ---
# uniq valid count:  124
# avg pkx:  7.940096663575265
# avg filtered scores  0.30079142264977615
# size _scaffolds  7618
# top-k reward mean:  0.4688145704776577
# ---
# uniq valid count:  123
# avg pkx:  8.107642860354197
# avg filtered scores  0.3521565898745361
# size _scaffolds  7641
# top-k reward mean:  0.48052099583388574
# --- 1780 ---
# ---
# uniq valid count:  127
# avg pkx:  7.9688260890265665
# avg filtered scores  0.3068240772194302
# size _scaffolds  7671
# top-k reward mean:  0.4753021974360977
# ---
# uniq valid count:  128
# avg pkx:  8.097214169840388
# avg filtered scores  0.3490958953733187
# size _scaffolds  7698
# top-k reward mean:  0.47810407902081986
# ---
# uniq valid count:  126
# avg pkx:  7.944149472452122
# avg filtered scores  0.3039835457583019
# size _scaffolds  7730
# top-k reward mean:  0.47594757473852445
# --- 1800 ---
# ---
# uniq valid count:  127
# avg pkx:  8.068671500779075
# avg filtered scores  0.329564114924979
# size _scaffolds  7761
# top-k reward mean:  0.47354786253614956
# ---
# uniq valid count:  124
# avg pkx:  8.053335264971263
# avg filtered scores  0.3424766372191775
# size _scaffolds  7797
# top-k reward mean:  0.4731999507852838
# ---
# uniq valid count:  127
# avg pkx:  8.065501329848663
# avg filtered scores  0.3363836833234131
# size _scaffolds  7825
# top-k reward mean:  0.47314556545728537
# ---
# uniq valid count:  124
# avg pkx:  8.041432401229866
# avg filtered scores  0.3095179366488158
# size _scaffolds  7855
# top-k reward mean:  0.4736088876422462
# --- 1820 ---
# ---
# uniq valid count:  127
# avg pkx:  8.128900659593496
# avg filtered scores  0.34225173025745426
# size _scaffolds  7876
# top-k reward mean:  0.47833955259436245
# ---
# uniq valid count:  125
# avg pkx:  8.02780390507476
# avg filtered scores  0.33809862035280003
# size _scaffolds  7908
# top-k reward mean:  0.4737759966273254
# ---
# uniq valid count:  127
# avg pkx:  8.147565678803266
# avg filtered scores  0.36351792925225473
# size _scaffolds  7936
# top-k reward mean:  0.47803454878252055
# --- 1840 ---
# ---
# uniq valid count:  125
# avg pkx:  8.019179879159013
# avg filtered scores  0.3289366960110295
# size _scaffolds  7961
# top-k reward mean:  0.47281176447835827
# ---
# uniq valid count:  125
# avg pkx:  8.132249869036698
# avg filtered scores  0.35853149113468247
# size _scaffolds  7986
# top-k reward mean:  0.47559883303899525
# ---
# uniq valid count:  126
# avg pkx:  7.956622393204445
# avg filtered scores  0.2976952808529689
# size _scaffolds  8021
# top-k reward mean:  0.4715973840692423
# --- 1860 ---
# ---
# uniq valid count:  125
# avg pkx:  8.070247071775771
# avg filtered scores  0.3420380578369315
# size _scaffolds  8049
# top-k reward mean:  0.4747439534088246
# ---
# uniq valid count:  126
# avg pkx:  7.842172200842816
# avg filtered scores  0.2839233982649458
# size _scaffolds  8077
# top-k reward mean:  0.4657187019725077
# ---
# uniq valid count:  128
# avg pkx:  8.063567358409136
# avg filtered scores  0.3393913087188447
# size _scaffolds  8110
# top-k reward mean:  0.4816159687147431
# ---
# uniq valid count:  123
# avg pkx:  8.094588052613979
# avg filtered scores  0.34687145639423134
# size _scaffolds  8138
# top-k reward mean:  0.4751732145735129
# --- 1880 ---
# ---
# uniq valid count:  127
# avg pkx:  8.074994820711025
# avg filtered scores  0.34164395147128324
# size _scaffolds  8173
# top-k reward mean:  0.4780517916530675
# ---
# uniq valid count:  123
# avg pkx:  8.03324533257771
# avg filtered scores  0.33085953842900645
# size _scaffolds  8208
# top-k reward mean:  0.4759126295868209
# ---
# uniq valid count:  126
# avg pkx:  7.9910301744148615
# avg filtered scores  0.3175529105874963
# size _scaffolds  8235
# top-k reward mean:  0.47126825488397106
# --- 1900 ---
# ---
# uniq valid count:  128
# avg pkx:  8.10501362324854
# avg filtered scores  0.3510242637295766
# size _scaffolds  8261
# top-k reward mean:  0.47646802111635783
# ---
# uniq valid count:  127
# avg pkx:  8.07687169808861
# avg filtered scores  0.32111590704992554
# size _scaffolds  8291
# top-k reward mean:  0.48008873417458703
# ---
# uniq valid count:  122
# avg pkx:  7.942170211557399
# avg filtered scores  0.29919481559103234
# size _scaffolds  8309
# top-k reward mean:  0.4688418978585479
# --- 1920 ---
# ---
# uniq valid count:  125
# avg pkx:  8.228358704611699
# avg filtered scores  0.3846995117808739
# size _scaffolds  8331
# top-k reward mean:  0.4826583788428213
# ---
# uniq valid count:  127
# avg pkx:  8.038616986019296
# avg filtered scores  0.32238178864284167
# size _scaffolds  8361
# top-k reward mean:  0.47549351514484606
# ---
# uniq valid count:  128
# avg pkx:  8.019217787022576
# avg filtered scores  0.32386630736452976
# size _scaffolds  8373
# top-k reward mean:  0.4726933206833701
# ---
# uniq valid count:  127
# avg pkx:  8.08887276542244
# avg filtered scores  0.3464873004356214
# size _scaffolds  8395
# top-k reward mean:  0.4761961315536762
# --- 1940 ---
# ---
# uniq valid count:  122
# avg pkx:  8.118397564819688
# avg filtered scores  0.3525118763591028
# size _scaffolds  8425
# top-k reward mean:  0.4769074725720635
# ---
# uniq valid count:  124
# avg pkx:  8.034190389359365
# avg filtered scores  0.33837163710598733
# size _scaffolds  8457
# top-k reward mean:  0.4772977055952718
# ---
# uniq valid count:  125
# avg pkx:  8.088309461954049
# avg filtered scores  0.3565967542535223
# size _scaffolds  8477
# top-k reward mean:  0.4752200270472926
# --- 1960 ---
# ---
# uniq valid count:  125
# avg pkx:  8.03644620078545
# avg filtered scores  0.33595933254891913
# size _scaffolds  8504
# top-k reward mean:  0.47664290695117467
# ---
# uniq valid count:  124
# avg pkx:  8.102911345194705
# avg filtered scores  0.34260360639947895
# size _scaffolds  8527
# top-k reward mean:  0.47566181010387804
# ---
# uniq valid count:  124
# avg pkx:  8.162858814952008
# avg filtered scores  0.357867022837535
# size _scaffolds  8558
# top-k reward mean:  0.4737199109770658
# --- 1980 ---
# ---
# uniq valid count:  126
# avg pkx:  8.100720855495293
# avg filtered scores  0.34273865520995256
# size _scaffolds  8589
# top-k reward mean:  0.4742366243299342
# ---
# uniq valid count:  126
# avg pkx:  8.05060463102924
# avg filtered scores  0.3374657150558912
# size _scaffolds  8609
# top-k reward mean:  0.47480548404479966
# ---
# uniq valid count:  124
# avg pkx:  8.07422157592986
# avg filtered scores  0.3320444155939925
# size _scaffolds  8640
# top-k reward mean:  0.47198480775751944
# ---
# uniq valid count:  125
# avg pkx:  7.979052813119394
# avg filtered scores  0.31353269064978573
# size _scaffolds  8662
# top-k reward mean:  0.4728300050845885
# --- 2000 ---

# %% [markdown]
# Subsidiary files building for evaluation phase

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # use tensorflow cpu

import fcd
import pickle
from logics_pack import frechet_chemnet
fc_ref_model = fcd.load_ref_model()

config.vc_fmt = project_paths['PROJECT_DIR'] + 'model-pik3ca/ahc/pik3ca_ahc_vc_e%d.smi'  # save valid & canonical smiles
config.npfps_fmt = project_paths['PROJECT_DIR'] + 'model-pik3ca/ahc/pik3ca_ahc_npfps_e%d.npy'  # save fingerprint in npy
config.fcvec_fmt = project_paths['PROJECT_DIR'] + 'model-pik3ca/ahc/pik3ca_ahc_fcvec_e%d.npy'  # save Frechet ChemNet vectors

epochs = list(range(0, config.max_epoch+1, config.save_period))
np.array(epochs)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3313: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2023-07-07 11:40:33.083825: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-07-07 11:40:33.122431: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-07 11:40:33.122498: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: shepherd6
# 2023-07-07 11:40:33.122517: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: shepherd6
# 2023-07-07 11:40:33.122700: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 465.19.1
# 2023-07-07 11:40:33.122770: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 465.19.1
# 2023-07-07 11:40:33.122789: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 465.19.1
# 2023-07-07 11:40:33.124395: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-07-07 11:40:33.160196: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299990000 Hz
# 2023-07-07 11:40:33.164155: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xafb8dd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-07-07 11:40:33.164251: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# array([   0,   20,   40,   60,   80,  100,  120,  140,  160,  180,  200,
#         220,  240,  260,  280,  300,  320,  340,  360,  380,  400,  420,
#         440,  460,  480,  500,  520,  540,  560,  580,  600,  620,  640,
#         660,  680,  700,  720,  740,  760,  780,  800,  820,  840,  860,
#         880,  900,  920,  940,  960,  980, 1000, 1020, 1040, 1060, 1080,
#        1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280, 1300,
#        1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520,
#        1540, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740,
#        1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960,
#        1980, 2000])

# %%
for epo in epochs:
    print(epo)
    with open(config.sample_fmt%epo, 'r') as f:
        gens = [line.strip() for line in f.readlines()]
    vcs, invids = chemistry.get_valid_canons(gens)
    print("- count invalids: ", len(invids))
    with open(config.vc_fmt%epo, 'w') as f:
        f.writelines([line+'\n' for line in vcs])
    fps = chemistry.get_fps_from_smilist(vcs)
    np.save(config.npfps_fmt%epo, chemistry.rdk2npfps(fps))
    fcvecs = fcd.get_predictions(fc_ref_model, vcs)  # ChemNet vectors
    np.save(config.fcvec_fmt%epo, fcvecs)
# Out:
# 0
# - count invalids:  985
# 20
# - count invalids:  1022
# 40
# - count invalids:  978
# 60
# - count invalids:  970
# 80
# - count invalids:  1038
# 100
# - count invalids:  1035
# 120
# - count invalids:  846
# 140
# - count invalids:  822
# 160
# - count invalids:  806
# 180
# - count invalids:  787
# 200
# - count invalids:  827
# 220
# - count invalids:  819
# 240
# - count invalids:  812
# 260
# - count invalids:  706
# 280
# - count invalids:  721
# 300
# - count invalids:  664
# 320
# - count invalids:  696
# 340
# - count invalids:  728
# 360
# - count invalids:  626
# 380
# - count invalids:  626
# 400
# - count invalids:  631
# 420
# - count invalids:  596
# 440
# - count invalids:  605
# 460
# - count invalids:  731
# 480
# - count invalids:  598
# 500
# - count invalids:  649
# 520
# - count invalids:  556
# 540
# - count invalids:  562
# 560
# - count invalids:  547
# 580
# - count invalids:  540
# 600
# - count invalids:  581
# 620
# - count invalids:  613
# 640
# - count invalids:  560
# 660
# - count invalids:  531
# 680
# - count invalids:  510
# 700
# - count invalids:  500
# 720
# - count invalids:  494
# 740
# - count invalids:  541
# 760
# - count invalids:  571
# 780
# - count invalids:  508
# 800
# - count invalids:  532
# 820
# - count invalids:  509
# 840
# - count invalids:  517
# 860
# - count invalids:  457
# 880
# - count invalids:  482
# 900
# - count invalids:  446
# 920
# - count invalids:  437
# 940
# - count invalids:  456
# 960
# - count invalids:  564
# 980
# - count invalids:  545
# 1000
# - count invalids:  546
# 1020
# - count invalids:  507
# 1040
# - count invalids:  453
# 1060
# - count invalids:  450
# 1080
# - count invalids:  492
# 1100
# - count invalids:  478
# 1120
# - count invalids:  442
# 1140
# - count invalids:  447
# 1160
# - count invalids:  456
# 1180
# - count invalids:  439
# 1200
# - count invalids:  465
# 1220
# - count invalids:  444
# 1240
# - count invalids:  438
# 1260
# - count invalids:  389
# 1280
# - count invalids:  461
# 1300
# - count invalids:  427
# 1320
# - count invalids:  464
# 1340
# - count invalids:  461
# 1360
# - count invalids:  446
# 1380
# - count invalids:  481
# 1400
# - count invalids:  399
# 1420
# - count invalids:  385
# 1440
# - count invalids:  401
# 1460
# - count invalids:  396
# 1480
# - count invalids:  426
# 1500
# - count invalids:  401
# 1520
# - count invalids:  376
# 1540
# - count invalids:  337
# 1560
# - count invalids:  417
# 1580
# - count invalids:  431
# 1600
# - count invalids:  409
# 1620
# - count invalids:  403
# 1640
# - count invalids:  432
# 1660
# - count invalids:  442
# 1680
# - count invalids:  426
# 1700
# - count invalids:  420
# 1720
# - count invalids:  405
# 1740
# - count invalids:  410
# 1760
# - count invalids:  470
# 1780
# - count invalids:  419
# 1800
# - count invalids:  362
# 1820
# - count invalids:  369
# 1840
# - count invalids:  383
# 1860
# - count invalids:  359
# 1880
# - count invalids:  399
# 1900
# - count invalids:  407
# 1920
# - count invalids:  363
# 1940
# - count invalids:  345
# 1960
# - count invalids:  391
# 1980
# - count invalids:  413
# 2000
# - count invalids:  439

# %% [markdown]
# Evaluate FCD and OTD on validation set, and pick the best epoch

# %%
# which validation fold recorded
vfold = expset_obj.get_setting("pik3ca-pred-best-cv")
vfold
# Out:
# '2'

# %%
affinity_data = pd.read_csv(project_paths['PIK3CA_DATA_PATH'])

# data split info
with open(project_paths['PIK3CA_FOLD_JSON'], 'r') as f:
    folds = json.load(f)

# retrieve validation set
val_ids = folds[vfold]
val_data = affinity_data.iloc[val_ids]

# get validation set activate (vsa)
vsa_data = val_data[val_data['affinity']>global_settings.PIK3CA_ACT_THRS]  # active among validation set
len(vsa_data)

vsa_smis = vsa_data['smiles'].tolist()
vsa_rdkfps = chemistry.get_fps_from_smilist(vsa_smis)
vsa_fc_vecs = fcd.get_predictions(fc_ref_model, vsa_smis)

dsize = len(vsa_rdkfps)  # demand size for OT
ssize = dsize*global_settings.OT_CALC_REPEATS  # supply size for repeated OT

# load predictor for PredAct (avg. predicted activity) calculation
with open(config.predictor_path, 'rb') as f:
    predictor = pickle.load(f)

# %%
val_fcd_list = []
val_otd_list = []
predact_list = []

for epo in epochs:
    print(epo)
    # load fc vectors of generation
    gen_fcvecs = np.load(config.fcvec_fmt%epo)
    fcdval = frechet_chemnet.fcd_calculation(gen_fcvecs, vsa_fc_vecs)
    val_fcd_list.append(fcdval)
    
    gen_npfps = np.load(config.npfps_fmt%epo)[:ssize]  # only need this amount
    gen_rdkfps = chemistry.np2rdkfps(gen_npfps)
    simmat = analysis.calculate_simmat(gen_rdkfps, vsa_rdkfps)  # row:gen, col:data
    distmat = analysis.transport_distmat(analysis.tansim_to_dist, simmat, global_settings.OT_CALC_REPEATS)
    _, _, motds = analysis.repeated_optimal_transport(distmat, repeat=global_settings.OT_CALC_REPEATS)
    val_otd_list.append(np.mean(motds))

    # record PredAct
    predact_list.append(np.mean(predictor.predict(gen_npfps)))
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000

# %%
# validation FCDxOTD
val_FCDxOTD = np.array(val_fcd_list)*np.array(val_otd_list)
# dataframe for validation performance
v_perf = pd.DataFrame(epochs, columns=['epoch'])
v_perf['v-OTDxFCD'] = val_FCDxOTD
v_perf['v-OTD'] = val_otd_list
v_perf['v-FCD'] = val_fcd_list
v_perf['PredAct'] = predact_list
v_perf
# Out:
#      epoch   v-OTDxFCD     v-OTD      v-FCD   PredAct
# 0        0  238.407451  6.002111  39.720600  6.841045
# 1       20  232.473061  5.965062  38.972450  6.898469
# 2       40  235.180997  5.953102  39.505623  6.958623
# 3       60  227.234618  5.884525  38.615627  7.005883
# 4       80  226.084201  5.892840  38.365917  7.044240
# ..     ...         ...       ...        ...       ...
# 96    1920  306.170447  5.970956  51.276621  8.068756
# 97    1940  306.752297  5.984850  51.254805  8.108896
# 98    1960  300.842114  5.971910  50.376199  8.093584
# 99    1980  298.363747  5.956041  50.094304  8.042051
# 100   2000  297.858261  5.963582  49.946198  8.055173
#
# [101 rows x 5 columns]

# %%
# we are only interested in epochs that achieved PredAct > (activity threshold)
subv = v_perf[v_perf['PredAct']>global_settings.PIK3CA_ACT_THRS].copy()

# find the best epoch
vbest = subv.loc[subv['v-OTDxFCD'].idxmin()]
print(vbest)

# register the best epoch
expset_obj.update_setting('pik3ca-ahc-best-epoch', int(vbest['epoch']))
# Out:
# epoch        1660.000000
# v-OTDxFCD     295.779663
# v-OTD           5.934146
# v-FCD          49.843674
# PredAct         8.043140
# Name: 83, dtype: float64

# %%
v_perf.to_csv(project_paths['PROJECT_DIR']+'model-pik3ca/pik3ca-ahc-vperf.csv', index=False)
