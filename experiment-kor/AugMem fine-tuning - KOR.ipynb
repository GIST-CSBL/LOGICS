# %%
import sys
sys.path.append('..')

# %%
from logics_pack import global_settings, chemistry, predictor, reward_functions, augmem
from logics_pack import analysis, smiles_vocab, smiles_lstm
import pandas as pd
import numpy as np
import json
import torch

project_paths = global_settings.build_project_paths(project_dir='../')
expset_obj = global_settings.ExperimentSettings(project_paths['EXPERIMENT_SETTINGS_JSON'])

# %% [markdown]
# Perform Augmented Memory fine-tuning to build agent generator

# %%
# AugMem fine-tuning config
config = global_settings.Object()
config.tokens_path = project_paths['SMILES_TOKENS_PATH']
config.pretrain_setting_path = project_paths['PRETRAIN_SETTING_JSON']
config.pretrained_model_path = project_paths['PROJECT_DIR'] + 'model-prior/prior_e10.ckpt'
config.featurizer = predictor.featurizer
config.predictor_path = project_paths['PROJECT_DIR'] + "model-kor/predictor/kor_rfr_cv%s.pkl"%expset_obj.get_setting("kor-pred-best-cv")

config.max_epoch = 2000  # "epoch" is actually the training batches for reinforcement learning models
config.save_period = 20
config.save_size = 20000
config.save_ckpt_fmt = project_paths['PROJECT_DIR'] + 'model-kor/augmem/kor_augmem_e%d.ckpt'
config.sample_fmt = project_paths['PROJECT_DIR'] + 'model-kor/augmem/kor_augmem_e%d.txt'
config.sigma = 20
config.memory_size = 200  ## AugMem
config.aug_rounds = 2  ## AugMem
config.nbmax = 25  ## DF
config.minscore = 0.5  ## we are using -1.0 ~ 1.0 range rewards
config.dfmode = "binary"  ## DF
config.rewarding = reward_functions.pAff_to_reward_t1
config.train_batch_size = 100
config.finetune_lr = 0.0004
config.sampling_bs = 256

config.device_name = 'cuda:1'  ####

# %%
augmem.AugmentedMemory_training(config)
# Out:
# --- 0 ---
# ---
# uniq valid count:  93
# avg pkx:  6.039153953746372
# avg filtered scores  -0.0473272438907125
# size _scaffolds  0
# mem score avg:  -0.047327243890712495
# size mem:  93
# ---
# uniq valid count:  98
# avg pkx:  6.078028324829931
# avg filtered scores  -0.038378463481088726
# size _scaffolds  4
# mem score avg:  0.1352968975304069
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  6.129725008865247
# avg filtered scores  -0.021052195631330452
# size _scaffolds  11
# mem score avg:  0.2286075966446143
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  6.173630132275132
# avg filtered scores  -0.008855604475336232
# size _scaffolds  16
# mem score avg:  0.2751283045911838
# size mem:  200
# --- 20 ---
# ---
# uniq valid count:  94
# avg pkx:  6.152590732016209
# avg filtered scores  -0.014499881790216634
# size _scaffolds  18
# mem score avg:  0.32190479625076857
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.2188747311827965
# avg filtered scores  0.004733298771583871
# size _scaffolds  24
# mem score avg:  0.3659890555205439
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.232339434203788
# avg filtered scores  0.008305470989133538
# size _scaffolds  31
# mem score avg:  0.39771500984883557
# size mem:  200
# --- 40 ---
# ---
# uniq valid count:  96
# avg pkx:  6.200390726686507
# avg filtered scores  -0.0011552074114116045
# size _scaffolds  37
# mem score avg:  0.42910428369401094
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.087921840277777
# avg filtered scores  -0.034025269456047495
# size _scaffolds  43
# mem score avg:  0.44893068960999377
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.313950859106528
# avg filtered scores  0.03254366196583826
# size _scaffolds  48
# mem score avg:  0.46251126739737297
# size mem:  200
# --- 60 ---
# ---
# uniq valid count:  91
# avg pkx:  6.262204442700156
# avg filtered scores  0.016338060172908887
# size _scaffolds  57
# mem score avg:  0.4776906342299621
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.261737325612532
# avg filtered scores  0.015453107109942145
# size _scaffolds  69
# mem score avg:  0.49743183261607116
# size mem:  200
# ---
# uniq valid count:  90
# avg pkx:  6.2057136111111095
# avg filtered scores  0.00042945371013509433
# size _scaffolds  76
# mem score avg:  0.5044319130909917
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.205825091765873
# avg filtered scores  0.00041721403912591166
# size _scaffolds  86
# mem score avg:  0.514683436923287
# size mem:  200
# --- 80 ---
# ---
# uniq valid count:  89
# avg pkx:  6.330404174692349
# avg filtered scores  0.03662075185554507
# size _scaffolds  95
# mem score avg:  0.5236351966547529
# size mem:  200
# ---
# uniq valid count:  90
# avg pkx:  6.407452962962964
# avg filtered scores  0.057142172806274004
# size _scaffolds  104
# mem score avg:  0.5326083792886783
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.267115558035715
# avg filtered scores  0.018916842107380444
# size _scaffolds  116
# mem score avg:  0.5416245992258554
# size mem:  200
# --- 100 ---
# ---
# uniq valid count:  94
# avg pkx:  6.186265406632375
# avg filtered scores  -0.004519217409303762
# size _scaffolds  131
# mem score avg:  0.5539559899843443
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  6.3698667375886515
# avg filtered scores  0.04754515639976607
# size _scaffolds  146
# mem score avg:  0.561542650305756
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.260471258503401
# avg filtered scores  0.013376798935868267
# size _scaffolds  164
# mem score avg:  0.5721279696703745
# size mem:  200
# --- 120 ---
# ---
# uniq valid count:  91
# avg pkx:  6.270514063317634
# avg filtered scores  0.019869663168908723
# size _scaffolds  183
# mem score avg:  0.5830755754880481
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  6.454090804865425
# avg filtered scores  0.06199268072157974
# size _scaffolds  203
# mem score avg:  0.5914257650315109
# size mem:  199
# ---
# uniq valid count:  98
# avg pkx:  6.572966350826044
# avg filtered scores  0.10208786188314144
# size _scaffolds  230
# mem score avg:  0.6025140592337834
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.476520300702882
# avg filtered scores  0.07479131702108936
# size _scaffolds  271
# mem score avg:  0.6110739041392632
# size mem:  200
# --- 140 ---
# ---
# uniq valid count:  96
# avg pkx:  6.444046684027778
# avg filtered scores  0.06649382579057977
# size _scaffolds  328
# mem score avg:  0.6197461677087742
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.402671361607143
# avg filtered scores  0.05046814401702852
# size _scaffolds  381
# mem score avg:  0.6263259735474435
# size mem:  200
# ---
# uniq valid count:  91
# avg pkx:  6.543888147566718
# avg filtered scores  0.0930061890782157
# size _scaffolds  444
# mem score avg:  0.629743230449083
# size mem:  200
# --- 160 ---
# ---
# uniq valid count:  96
# avg pkx:  6.5268635887896815
# avg filtered scores  0.08912032587376632
# size _scaffolds  504
# mem score avg:  0.6325862899952648
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.75578347718254
# avg filtered scores  0.14714502186469008
# size _scaffolds  568
# mem score avg:  0.6372739714857296
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.624677419354839
# avg filtered scores  0.1140737634714832
# size _scaffolds  635
# mem score avg:  0.6386665963472532
# size mem:  200
# --- 180 ---
# ---
# uniq valid count:  91
# avg pkx:  6.417253979591838
# avg filtered scores  0.05718456820649088
# size _scaffolds  681
# mem score avg:  0.6392403633914582
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.726270195932539
# avg filtered scores  0.14002233493191588
# size _scaffolds  754
# mem score avg:  0.6434832918181098
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.4455310824742265
# avg filtered scores  0.06501419387999634
# size _scaffolds  822
# mem score avg:  0.6471374915898881
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.823656681547619
# avg filtered scores  0.16734674417889858
# size _scaffolds  900
# mem score avg:  0.6505382020438653
# size mem:  200
# --- 200 ---
# ---
# uniq valid count:  93
# avg pkx:  6.517014109062978
# avg filtered scores  0.08315565854195528
# size _scaffolds  975
# mem score avg:  0.6527685357731831
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.722693901846453
# avg filtered scores  0.133535199419963
# size _scaffolds  1060
# mem score avg:  0.6557339740546717
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  6.626834788657036
# avg filtered scores  0.11357300721224733
# size _scaffolds  1133
# mem score avg:  0.6566943091437549
# size mem:  200
# --- 220 ---
# ---
# uniq valid count:  96
# avg pkx:  6.666364930555556
# avg filtered scores  0.12220869741985918
# size _scaffolds  1216
# mem score avg:  0.6601181117290011
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.764589965635739
# avg filtered scores  0.15312418593235402
# size _scaffolds  1285
# mem score avg:  0.6637138601260355
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.73010591350826
# avg filtered scores  0.13819192321664586
# size _scaffolds  1372
# mem score avg:  0.6661031366187977
# size mem:  200
# --- 240 ---
# ---
# uniq valid count:  96
# avg pkx:  6.647365466269842
# avg filtered scores  0.1179784374223624
# size _scaffolds  1465
# mem score avg:  0.6691225207223016
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  6.672311671732523
# avg filtered scores  0.12294157705705046
# size _scaffolds  1551
# mem score avg:  0.6704435613103399
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  6.895123862155387
# avg filtered scores  0.1740806437089351
# size _scaffolds  1622
# mem score avg:  0.6712914292027548
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.732187196180555
# avg filtered scores  0.1336934010010958
# size _scaffolds  1702
# mem score avg:  0.6727633380113535
# size mem:  200
# --- 260 ---
# ---
# uniq valid count:  96
# avg pkx:  6.790657524801588
# avg filtered scores  0.15183817349686676
# size _scaffolds  1795
# mem score avg:  0.6740010680971316
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.732243756200397
# avg filtered scores  0.13858806335170953
# size _scaffolds  1870
# mem score avg:  0.6751838270581149
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.860350086805556
# avg filtered scores  0.16720484934646632
# size _scaffolds  1952
# mem score avg:  0.6762104699648563
# size mem:  200
# --- 280 ---
# ---
# uniq valid count:  97
# avg pkx:  6.879041666666666
# avg filtered scores  0.1708016292419845
# size _scaffolds  2039
# mem score avg:  0.677476033595369
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.805432658730159
# avg filtered scores  0.1559446192723318
# size _scaffolds  2128
# mem score avg:  0.6786798356576014
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.872132060931898
# avg filtered scores  0.17302269262209993
# size _scaffolds  2238
# mem score avg:  0.6806396897555408
# size mem:  200
# --- 300 ---
# ---
# uniq valid count:  93
# avg pkx:  6.84034219406042
# avg filtered scores  0.17474581977919884
# size _scaffolds  2335
# mem score avg:  0.6822597343602027
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  6.674557454710146
# avg filtered scores  0.10780025137557157
# size _scaffolds  2422
# mem score avg:  0.6835469640898567
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  6.593886877192983
# avg filtered scores  0.10607989381830045
# size _scaffolds  2510
# mem score avg:  0.6838376640904553
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.839599045138889
# avg filtered scores  0.16388101281491269
# size _scaffolds  2594
# mem score avg:  0.6846748966143895
# size mem:  200
# --- 320 ---
# ---
# uniq valid count:  95
# avg pkx:  6.805908621553884
# avg filtered scores  0.14352706125973802
# size _scaffolds  2687
# mem score avg:  0.6857927848412261
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.999905076884922
# avg filtered scores  0.20695925156182002
# size _scaffolds  2774
# mem score avg:  0.6860758910364189
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.041668173363096
# avg filtered scores  0.21221193704994165
# size _scaffolds  2874
# mem score avg:  0.6869160232915786
# size mem:  200
# --- 340 ---
# ---
# uniq valid count:  94
# avg pkx:  7.029099328774065
# avg filtered scores  0.21118000300991252
# size _scaffolds  2958
# mem score avg:  0.6882005347752522
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.8506130034722235
# avg filtered scores  0.16400229910694503
# size _scaffolds  3048
# mem score avg:  0.6886964668146126
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.870234474717722
# avg filtered scores  0.17848890935222622
# size _scaffolds  3163
# mem score avg:  0.6891802281320443
# size mem:  200
# --- 360 ---
# ---
# uniq valid count:  95
# avg pkx:  6.950646270676691
# avg filtered scores  0.18126348773620526
# size _scaffolds  3270
# mem score avg:  0.6900123618939945
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  6.952251315924219
# avg filtered scores  0.19257333097051593
# size _scaffolds  3368
# mem score avg:  0.6910531707973435
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.890523235149731
# avg filtered scores  0.1718665030558797
# size _scaffolds  3477
# mem score avg:  0.6919742612420026
# size mem:  199
# ---
# uniq valid count:  95
# avg pkx:  6.780887481203009
# avg filtered scores  0.13840741376825058
# size _scaffolds  3577
# mem score avg:  0.6930764929626594
# size mem:  200
# --- 380 ---
# ---
# uniq valid count:  98
# avg pkx:  6.980029956268221
# avg filtered scores  0.1936807267818143
# size _scaffolds  3672
# mem score avg:  0.6932167023946582
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.914692869415808
# avg filtered scores  0.174598689120131
# size _scaffolds  3765
# mem score avg:  0.6940631794040997
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.637534672200653
# avg filtered scores  0.11531138994147255
# size _scaffolds  3857
# mem score avg:  0.694507055096585
# size mem:  200
# --- 400 ---
# ---
# uniq valid count:  96
# avg pkx:  7.178878385416667
# avg filtered scores  0.23332143809798878
# size _scaffolds  3959
# mem score avg:  0.6954853374530202
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.041727538046146
# avg filtered scores  0.2170478634930579
# size _scaffolds  4063
# mem score avg:  0.6960466724347537
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.105569727891157
# avg filtered scores  0.22697993060088986
# size _scaffolds  4183
# mem score avg:  0.6966553092128075
# size mem:  200
# --- 420 ---
# ---
# uniq valid count:  96
# avg pkx:  7.181364248511905
# avg filtered scores  0.2488561503056784
# size _scaffolds  4287
# mem score avg:  0.6966790725985075
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.024504647817461
# avg filtered scores  0.1990710055669025
# size _scaffolds  4403
# mem score avg:  0.6978820818174993
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.896381502209131
# avg filtered scores  0.17292116269740734
# size _scaffolds  4491
# mem score avg:  0.6982256749434497
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.070839210526316
# avg filtered scores  0.22101097897536362
# size _scaffolds  4581
# mem score avg:  0.6992228664134353
# size mem:  200
# --- 440 ---
# ---
# uniq valid count:  97
# avg pkx:  7.225040367370315
# avg filtered scores  0.25172682999081786
# size _scaffolds  4699
# mem score avg:  0.700039332065908
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.132983948412698
# avg filtered scores  0.2291095966756139
# size _scaffolds  4793
# mem score avg:  0.7007984810223601
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.100566938775511
# avg filtered scores  0.218838135351406
# size _scaffolds  4901
# mem score avg:  0.701486227199004
# size mem:  200
# --- 460 ---
# ---
# uniq valid count:  98
# avg pkx:  7.140539579689019
# avg filtered scores  0.22204340243825435
# size _scaffolds  4998
# mem score avg:  0.7029998708614087
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.972928384353743
# avg filtered scores  0.18208883255848382
# size _scaffolds  5093
# mem score avg:  0.703795984747083
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.037779508928572
# avg filtered scores  0.2223547764930264
# size _scaffolds  5202
# mem score avg:  0.7043286322674153
# size mem:  200
# --- 480 ---
# ---
# uniq valid count:  96
# avg pkx:  6.99285459077381
# avg filtered scores  0.19957097440748547
# size _scaffolds  5300
# mem score avg:  0.7046793374695582
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.179227814536341
# avg filtered scores  0.24470293222474163
# size _scaffolds  5428
# mem score avg:  0.7055215769431358
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  6.827241907166908
# avg filtered scores  0.14481433177944247
# size _scaffolds  5542
# mem score avg:  0.705991250315011
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.072594612174768
# avg filtered scores  0.19479300974461114
# size _scaffolds  5654
# mem score avg:  0.7061775257234642
# size mem:  200
# --- 500 ---
# ---
# uniq valid count:  98
# avg pkx:  7.144179565111759
# avg filtered scores  0.23679345942894606
# size _scaffolds  5748
# mem score avg:  0.7064126435068799
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.977886941580758
# avg filtered scores  0.17532917021548217
# size _scaffolds  5857
# mem score avg:  0.706935024211436
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  6.8754632341269835
# avg filtered scores  0.16594618132978112
# size _scaffolds  5942
# mem score avg:  0.7083260702614035
# size mem:  200
# --- 520 ---
# ---
# uniq valid count:  97
# avg pkx:  7.123619403534609
# avg filtered scores  0.2404657170705437
# size _scaffolds  6057
# mem score avg:  0.7090543632916976
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.917978078231293
# avg filtered scores  0.17983689563946895
# size _scaffolds  6132
# mem score avg:  0.7092222917125948
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.059520421052633
# avg filtered scores  0.2036393038016769
# size _scaffolds  6226
# mem score avg:  0.709806744969263
# size mem:  200
# --- 540 ---
# ---
# uniq valid count:  97
# avg pkx:  7.111831956308298
# avg filtered scores  0.22268499622180815
# size _scaffolds  6321
# mem score avg:  0.7099256817172076
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  6.982980663265305
# avg filtered scores  0.1914603349731318
# size _scaffolds  6416
# mem score avg:  0.7096334585489618
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.212471547619048
# avg filtered scores  0.24465184967760154
# size _scaffolds  6516
# mem score avg:  0.7101213697541222
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.089752295918367
# avg filtered scores  0.21854320045795536
# size _scaffolds  6616
# mem score avg:  0.7112909908834216
# size mem:  200
# --- 560 ---
# ---
# uniq valid count:  98
# avg pkx:  6.906999368318756
# avg filtered scores  0.18108159365547946
# size _scaffolds  6724
# mem score avg:  0.7121531188941532
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.041328984375002
# avg filtered scores  0.21314018037343851
# size _scaffolds  6809
# mem score avg:  0.7120055846446682
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.148285444280805
# avg filtered scores  0.24130377613409132
# size _scaffolds  6920
# mem score avg:  0.713042746516666
# size mem:  200
# --- 580 ---
# ---
# uniq valid count:  97
# avg pkx:  7.1608738316151195
# avg filtered scores  0.22039428084655394
# size _scaffolds  7026
# mem score avg:  0.7134143683079741
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.153847979872361
# avg filtered scores  0.21005094130705282
# size _scaffolds  7119
# mem score avg:  0.713811912238504
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.031666052414021
# avg filtered scores  0.20311907463664744
# size _scaffolds  7214
# mem score avg:  0.7141922302000568
# size mem:  200
# --- 600 ---
# ---
# uniq valid count:  99
# avg pkx:  7.284932104377104
# avg filtered scores  0.2641521279924064
# size _scaffolds  7326
# mem score avg:  0.7146041307394756
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.230927378497791
# avg filtered scores  0.26424582794551915
# size _scaffolds  7417
# mem score avg:  0.7149359559672399
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.094393612730808
# avg filtered scores  0.20423424288130615
# size _scaffolds  7522
# mem score avg:  0.7151628146445813
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.0494611634757005
# avg filtered scores  0.17973806731642514
# size _scaffolds  7611
# mem score avg:  0.7145906151450272
# size mem:  200
# --- 620 ---
# ---
# uniq valid count:  96
# avg pkx:  6.960147853518009
# avg filtered scores  0.18060520904360744
# size _scaffolds  7721
# mem score avg:  0.7152233387767987
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.1917086597938145
# avg filtered scores  0.24211174932560622
# size _scaffolds  7824
# mem score avg:  0.7159006480191225
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.106849079528719
# avg filtered scores  0.2386096639853352
# size _scaffolds  7906
# mem score avg:  0.7160023213538008
# size mem:  200
# --- 640 ---
# ---
# uniq valid count:  98
# avg pkx:  7.087386972789116
# avg filtered scores  0.2064503557293173
# size _scaffolds  7988
# mem score avg:  0.7169038269798057
# size mem:  199
# ---
# uniq valid count:  95
# avg pkx:  7.0405257894736835
# avg filtered scores  0.1879050305274885
# size _scaffolds  8093
# mem score avg:  0.7172916164532236
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.179567418946302
# avg filtered scores  0.2477616392169959
# size _scaffolds  8188
# mem score avg:  0.7177735842530069
# size mem:  200
# --- 660 ---
# ---
# uniq valid count:  96
# avg pkx:  7.186190771329366
# avg filtered scores  0.23092947148442902
# size _scaffolds  8287
# mem score avg:  0.7179872243494865
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.066616953933749
# avg filtered scores  0.20711714737367193
# size _scaffolds  8373
# mem score avg:  0.7187821178504933
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.2498686278195485
# avg filtered scores  0.24405542303666933
# size _scaffolds  8459
# mem score avg:  0.7188972842626717
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.218546897163121
# avg filtered scores  0.23927503178043674
# size _scaffolds  8553
# mem score avg:  0.719196488373584
# size mem:  200
# --- 680 ---
# ---
# uniq valid count:  99
# avg pkx:  7.2555039562289565
# avg filtered scores  0.2644088030987005
# size _scaffolds  8659
# mem score avg:  0.7198053073270283
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.149227448979593
# avg filtered scores  0.24137398141020658
# size _scaffolds  8772
# mem score avg:  0.7199524771330872
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.09384261168385
# avg filtered scores  0.21309554126142669
# size _scaffolds  8863
# mem score avg:  0.7206311192570469
# size mem:  200
# --- 700 ---
# ---
# uniq valid count:  98
# avg pkx:  7.286034674441207
# avg filtered scores  0.2641061244332762
# size _scaffolds  8965
# mem score avg:  0.7206991493899096
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.196133197278911
# avg filtered scores  0.24130057271263702
# size _scaffolds  9075
# mem score avg:  0.7210181043915622
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.995203615611194
# avg filtered scores  0.18396189033851182
# size _scaffolds  9184
# mem score avg:  0.7213599475996526
# size mem:  200
# --- 720 ---
# ---
# uniq valid count:  94
# avg pkx:  7.035783220502902
# avg filtered scores  0.19680969735285017
# size _scaffolds  9284
# mem score avg:  0.7214219002552815
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.324440353535352
# avg filtered scores  0.2813213576759767
# size _scaffolds  9383
# mem score avg:  0.7215535896711839
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.0680294636844625
# avg filtered scores  0.20549790469338775
# size _scaffolds  9470
# mem score avg:  0.7216612129631835
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.3353774392614195
# avg filtered scores  0.26656240355067173
# size _scaffolds  9569
# mem score avg:  0.722428889159505
# size mem:  200
# --- 740 ---
# ---
# uniq valid count:  96
# avg pkx:  7.150301316964286
# avg filtered scores  0.22495641580950823
# size _scaffolds  9678
# mem score avg:  0.7225986455812984
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.136575975699559
# avg filtered scores  0.21964995572389817
# size _scaffolds  9776
# mem score avg:  0.7226925658973407
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.298633380456351
# avg filtered scores  0.28102327496343804
# size _scaffolds  9870
# mem score avg:  0.7226925658973407
# size mem:  200
# --- 760 ---
# ---
# uniq valid count:  98
# avg pkx:  7.12934987852284
# avg filtered scores  0.2336418503894061
# size _scaffolds  9969
# mem score avg:  0.7226925658973407
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.313506352040818
# avg filtered scores  0.2705755264317227
# size _scaffolds  10066
# mem score avg:  0.7231528228298513
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  6.912271218703976
# avg filtered scores  0.17219199776856622
# size _scaffolds  10147
# mem score avg:  0.7209173754910256
# size mem:  199
# --- 780 ---
# ---
# uniq valid count:  99
# avg pkx:  7.22815163889982
# avg filtered scores  0.25374686892763293
# size _scaffolds  10260
# mem score avg:  0.7231205104781858
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.17085767609127
# avg filtered scores  0.24769377998155975
# size _scaffolds  10359
# mem score avg:  0.7236590967299779
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.003322137947962
# avg filtered scores  0.18852289288678986
# size _scaffolds  10452
# mem score avg:  0.7240793868733064
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.017848723958333
# avg filtered scores  0.21039262823277746
# size _scaffolds  10547
# mem score avg:  0.724133242949547
# size mem:  200
# --- 800 ---
# ---
# uniq valid count:  93
# avg pkx:  7.120968620071685
# avg filtered scores  0.23362926124924202
# size _scaffolds  10636
# mem score avg:  0.7243822332702965
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.002631824586979
# avg filtered scores  0.2042899271804435
# size _scaffolds  10715
# mem score avg:  0.7245704444610993
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.322930286738351
# avg filtered scores  0.2710578129822274
# size _scaffolds  10818
# mem score avg:  0.7248468717947208
# size mem:  200
# --- 820 ---
# ---
# uniq valid count:  96
# avg pkx:  7.11254828125
# avg filtered scores  0.23606333247043365
# size _scaffolds  10900
# mem score avg:  0.7250056738022151
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.280080612244899
# avg filtered scores  0.255224542927632
# size _scaffolds  10984
# mem score avg:  0.7254302134538619
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.0689725680272115
# avg filtered scores  0.20267028236311743
# size _scaffolds  11086
# mem score avg:  0.7261862675900611
# size mem:  198
# --- 840 ---
# ---
# uniq valid count:  96
# avg pkx:  7.3187383680555556
# avg filtered scores  0.2937265193409478
# size _scaffolds  11183
# mem score avg:  0.7261809291399421
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.1708836552478115
# avg filtered scores  0.23331348552573228
# size _scaffolds  11273
# mem score avg:  0.726374517300227
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.229898971526755
# avg filtered scores  0.27469745925465316
# size _scaffolds  11377
# mem score avg:  0.7269102437519064
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.157941028708135
# avg filtered scores  0.2533596813702458
# size _scaffolds  11485
# mem score avg:  0.7271522962335842
# size mem:  200
# --- 860 ---
# ---
# uniq valid count:  97
# avg pkx:  7.375954852724596
# avg filtered scores  0.284372521424858
# size _scaffolds  11596
# mem score avg:  0.7273610734424572
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.178943554421769
# avg filtered scores  0.24741355610596374
# size _scaffolds  11692
# mem score avg:  0.7275022114649531
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.322663684339714
# avg filtered scores  0.2702528263576655
# size _scaffolds  11778
# mem score avg:  0.7277748978542796
# size mem:  200
# --- 880 ---
# ---
# uniq valid count:  97
# avg pkx:  6.97341660652921
# avg filtered scores  0.18957111361512932
# size _scaffolds  11868
# mem score avg:  0.7280801867739464
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.268826280701754
# avg filtered scores  0.2706071771859943
# size _scaffolds  11969
# mem score avg:  0.7286653579142833
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.329215184645287
# avg filtered scores  0.25729095040878364
# size _scaffolds  12070
# mem score avg:  0.7288337634695361
# size mem:  200
# --- 900 ---
# ---
# uniq valid count:  99
# avg pkx:  7.107653367003367
# avg filtered scores  0.2165292770287332
# size _scaffolds  12171
# mem score avg:  0.7291748096215619
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.1848168707483
# avg filtered scores  0.26101465418365793
# size _scaffolds  12268
# mem score avg:  0.728363958697404
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.282946394927536
# avg filtered scores  0.27905663326120456
# size _scaffolds  12372
# mem score avg:  0.7304233591612078
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.043483340621963
# avg filtered scores  0.20892700548490573
# size _scaffolds  12473
# mem score avg:  0.7306025181756843
# size mem:  200
# --- 920 ---
# ---
# uniq valid count:  97
# avg pkx:  7.307105510554736
# avg filtered scores  0.28492708606596695
# size _scaffolds  12581
# mem score avg:  0.7307560399530982
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.28190622895623
# avg filtered scores  0.2717779550959651
# size _scaffolds  12671
# mem score avg:  0.7311181493546731
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.251209510309279
# avg filtered scores  0.2644058257950302
# size _scaffolds  12749
# mem score avg:  0.7315287846858886
# size mem:  200
# --- 940 ---
# ---
# uniq valid count:  97
# avg pkx:  7.245974577810506
# avg filtered scores  0.26272241614474523
# size _scaffolds  12851
# mem score avg:  0.7320633976720154
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.14593250728863
# avg filtered scores  0.24157246648995903
# size _scaffolds  12959
# mem score avg:  0.7322042835148231
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.476224727891156
# avg filtered scores  0.3272260645171907
# size _scaffolds  13068
# mem score avg:  0.7324702825563526
# size mem:  200
# --- 960 ---
# ---
# uniq valid count:  97
# avg pkx:  7.423663728522338
# avg filtered scores  0.28637688082809604
# size _scaffolds  13177
# mem score avg:  0.7327516111752178
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.141312490281827
# avg filtered scores  0.23202624066054012
# size _scaffolds  13267
# mem score avg:  0.7330646709622778
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.305871305841924
# avg filtered scores  0.2609343822433649
# size _scaffolds  13369
# mem score avg:  0.733250085138248
# size mem:  199
# ---
# uniq valid count:  96
# avg pkx:  7.35559095982143
# avg filtered scores  0.3055449752369621
# size _scaffolds  13466
# mem score avg:  0.7333408947535612
# size mem:  200
# --- 980 ---
# ---
# uniq valid count:  97
# avg pkx:  7.358653591065291
# avg filtered scores  0.2701932197702815
# size _scaffolds  13567
# mem score avg:  0.7339887640223502
# size mem:  195
# ---
# uniq valid count:  93
# avg pkx:  7.399179336917562
# avg filtered scores  0.31065478081226183
# size _scaffolds  13672
# mem score avg:  0.733812549669208
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.282340309017225
# avg filtered scores  0.2642383326097882
# size _scaffolds  13749
# mem score avg:  0.7345270249983009
# size mem:  200
# --- 1000 ---
# ---
# uniq valid count:  96
# avg pkx:  7.49278515625
# avg filtered scores  0.31837935991486077
# size _scaffolds  13840
# mem score avg:  0.7350580242004525
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.180854971139971
# avg filtered scores  0.25990581908205473
# size _scaffolds  13922
# mem score avg:  0.7353568449655526
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.445179523809525
# avg filtered scores  0.2940478399526146
# size _scaffolds  14013
# mem score avg:  0.7358621458766021
# size mem:  199
# --- 1020 ---
# ---
# uniq valid count:  95
# avg pkx:  7.31421888471178
# avg filtered scores  0.2672845375984432
# size _scaffolds  14103
# mem score avg:  0.735808368006656
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.372073246527777
# avg filtered scores  0.30006061865729133
# size _scaffolds  14203
# mem score avg:  0.7359801219482565
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.188399722222222
# avg filtered scores  0.2467973617719522
# size _scaffolds  14301
# mem score avg:  0.7364838624558899
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.366551838487973
# avg filtered scores  0.2906610741045972
# size _scaffolds  14404
# mem score avg:  0.7366011373419303
# size mem:  200
# --- 1040 ---
# ---
# uniq valid count:  92
# avg pkx:  7.37909783126294
# avg filtered scores  0.3029273932574179
# size _scaffolds  14515
# mem score avg:  0.736886776285809
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.432560789473683
# avg filtered scores  0.27097261001441275
# size _scaffolds  14611
# mem score avg:  0.7368242556008058
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.3597192097264434
# avg filtered scores  0.2982380604060145
# size _scaffolds  14704
# mem score avg:  0.7374179756304367
# size mem:  200
# --- 1060 ---
# ---
# uniq valid count:  93
# avg pkx:  7.356457320788531
# avg filtered scores  0.2749173879453335
# size _scaffolds  14794
# mem score avg:  0.7377397343582868
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.266152916666667
# avg filtered scores  0.2694202680185643
# size _scaffolds  14885
# mem score avg:  0.738142836470864
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.396285606060607
# avg filtered scores  0.26988888319427706
# size _scaffolds  15015
# mem score avg:  0.7383157456878999
# size mem:  200
# --- 1080 ---
# ---
# uniq valid count:  96
# avg pkx:  7.089770709325397
# avg filtered scores  0.2066419009655968
# size _scaffolds  15110
# mem score avg:  0.7383919771239631
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.402874484536084
# avg filtered scores  0.2806722887131001
# size _scaffolds  15212
# mem score avg:  0.7390668752246994
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.367011
# avg filtered scores  0.28564679087867334
# size _scaffolds  15323
# mem score avg:  0.7390977965771232
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.379629010416667
# avg filtered scores  0.2885061204587365
# size _scaffolds  15449
# mem score avg:  0.7386120890843366
# size mem:  200
# --- 1100 ---
# ---
# uniq valid count:  95
# avg pkx:  7.289170761904761
# avg filtered scores  0.26461573321610954
# size _scaffolds  15551
# mem score avg:  0.7387296506860825
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.296051011695905
# avg filtered scores  0.28497391704837416
# size _scaffolds  15652
# mem score avg:  0.7391036912669361
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.4655909450171825
# avg filtered scores  0.32028540416141577
# size _scaffolds  15758
# mem score avg:  0.739311026115671
# size mem:  200
# --- 1120 ---
# ---
# uniq valid count:  100
# avg pkx:  7.431807883333334
# avg filtered scores  0.3174737311399489
# size _scaffolds  15864
# mem score avg:  0.7394303264090408
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.326302551020407
# avg filtered scores  0.29388200352658445
# size _scaffolds  15961
# mem score avg:  0.7397615298393609
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.452451700680274
# avg filtered scores  0.33869035834903116
# size _scaffolds  16067
# mem score avg:  0.7398459877187371
# size mem:  200
# --- 1140 ---
# ---
# uniq valid count:  98
# avg pkx:  7.336902363945577
# avg filtered scores  0.2897488206930949
# size _scaffolds  16178
# mem score avg:  0.740408551310872
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.468061021109476
# avg filtered scores  0.3131102110733531
# size _scaffolds  16271
# mem score avg:  0.7409799137470503
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.202187892230575
# avg filtered scores  0.24690477636471422
# size _scaffolds  16380
# mem score avg:  0.7413284924362966
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.309192239057239
# avg filtered scores  0.2764635302958199
# size _scaffolds  16476
# mem score avg:  0.741654220044042
# size mem:  200
# --- 1160 ---
# ---
# uniq valid count:  95
# avg pkx:  7.227050414673045
# avg filtered scores  0.25485631363449324
# size _scaffolds  16563
# mem score avg:  0.7421230215872437
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.176245314187531
# avg filtered scores  0.23722888529804786
# size _scaffolds  16656
# mem score avg:  0.7424128834796527
# size mem:  198
# ---
# uniq valid count:  94
# avg pkx:  7.329793971631208
# avg filtered scores  0.24301337480692287
# size _scaffolds  16751
# mem score avg:  0.742630650146811
# size mem:  199
# --- 1180 ---
# ---
# uniq valid count:  96
# avg pkx:  7.385291860119048
# avg filtered scores  0.28640826129210517
# size _scaffolds  16843
# mem score avg:  0.742518716398024
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.475362425595239
# avg filtered scores  0.2645132685686143
# size _scaffolds  16929
# mem score avg:  0.7427137614360546
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.458151275510205
# avg filtered scores  0.32198159158386774
# size _scaffolds  17039
# mem score avg:  0.742757866996902
# size mem:  200
# --- 1200 ---
# ---
# uniq valid count:  98
# avg pkx:  7.2298566326530604
# avg filtered scores  0.23346154743558392
# size _scaffolds  17131
# mem score avg:  0.7430568047399833
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.49064752786221
# avg filtered scores  0.3144487573683005
# size _scaffolds  17245
# mem score avg:  0.7432034046269639
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.53960990942029
# avg filtered scores  0.32452253723812924
# size _scaffolds  17365
# mem score avg:  0.7436880610316414
# size mem:  200
# ---
# uniq valid count:  99
# avg pkx:  7.756125925925927
# avg filtered scores  0.3827357546829492
# size _scaffolds  17467
# mem score avg:  0.7441437672632017
# size mem:  200
# --- 1220 ---
# ---
# uniq valid count:  95
# avg pkx:  7.41898063157895
# avg filtered scores  0.31447173089219677
# size _scaffolds  17561
# mem score avg:  0.7441962549274311
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.304146979166667
# avg filtered scores  0.2872236638144603
# size _scaffolds  17650
# mem score avg:  0.7442143688689685
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.389129545675414
# avg filtered scores  0.2854367450640398
# size _scaffolds  17753
# mem score avg:  0.7438336179968936
# size mem:  200
# --- 1240 ---
# ---
# uniq valid count:  92
# avg pkx:  7.472971096014492
# avg filtered scores  0.3156426265537414
# size _scaffolds  17869
# mem score avg:  0.7441937256735343
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.450807960992908
# avg filtered scores  0.3046094410816538
# size _scaffolds  17968
# mem score avg:  0.7443240028367825
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.318470220174092
# avg filtered scores  0.2750015044329534
# size _scaffolds  18067
# mem score avg:  0.7445272079867072
# size mem:  200
# --- 1260 ---
# ---
# uniq valid count:  96
# avg pkx:  7.338081336805556
# avg filtered scores  0.25640594629079455
# size _scaffolds  18179
# mem score avg:  0.7445749739447531
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.565356254480288
# avg filtered scores  0.3243181440115007
# size _scaffolds  18289
# mem score avg:  0.744698944265805
# size mem:  198
# ---
# uniq valid count:  97
# avg pkx:  7.40513528227786
# avg filtered scores  0.30928124427159137
# size _scaffolds  18406
# mem score avg:  0.7445676252554763
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.517414062499999
# avg filtered scores  0.3269022117316067
# size _scaffolds  18528
# mem score avg:  0.7444704583080539
# size mem:  200
# --- 1280 ---
# ---
# uniq valid count:  93
# avg pkx:  7.32575770609319
# avg filtered scores  0.27189022240284233
# size _scaffolds  18643
# mem score avg:  0.744756168613543
# size mem:  199
# ---
# uniq valid count:  97
# avg pkx:  7.4093835738831615
# avg filtered scores  0.3125509491973132
# size _scaffolds  18743
# mem score avg:  0.7449229867712028
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.470289311594204
# avg filtered scores  0.2899384020029462
# size _scaffolds  18852
# mem score avg:  0.7449229867712028
# size mem:  200
# --- 1300 ---
# ---
# uniq valid count:  96
# avg pkx:  7.477707048611111
# avg filtered scores  0.31146777685481636
# size _scaffolds  18966
# mem score avg:  0.7445097976748815
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.48144530612245
# avg filtered scores  0.27487222981620063
# size _scaffolds  19076
# mem score avg:  0.7447245806352811
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.512209097222223
# avg filtered scores  0.3303129124160526
# size _scaffolds  19190
# mem score avg:  0.7451653931187798
# size mem:  200
# --- 1320 ---
# ---
# uniq valid count:  94
# avg pkx:  7.614836712259373
# avg filtered scores  0.33620446927726483
# size _scaffolds  19308
# mem score avg:  0.7454889928978481
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.3423285638297875
# avg filtered scores  0.2722268609221761
# size _scaffolds  19416
# mem score avg:  0.7453649532844631
# size mem:  196
# ---
# uniq valid count:  95
# avg pkx:  7.35662234085213
# avg filtered scores  0.2644618488921025
# size _scaffolds  19520
# mem score avg:  0.7452071696766517
# size mem:  198
# ---
# uniq valid count:  96
# avg pkx:  7.630414756944444
# avg filtered scores  0.3355420406636361
# size _scaffolds  19642
# mem score avg:  0.7454121330876463
# size mem:  199
# --- 1340 ---
# ---
# uniq valid count:  96
# avg pkx:  7.529250890376985
# avg filtered scores  0.3268070839986342
# size _scaffolds  19773
# mem score avg:  0.7451848117432982
# size mem:  200
# ---
# uniq valid count:  96
# avg pkx:  7.345200059523811
# avg filtered scores  0.23119425550693487
# size _scaffolds  19887
# mem score avg:  0.7463641675874245
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.52452100340136
# avg filtered scores  0.33217649765227936
# size _scaffolds  20000
# mem score avg:  0.7461475278473075
# size mem:  200
# --- 1360 ---
# ---
# uniq valid count:  95
# avg pkx:  7.285520789473685
# avg filtered scores  0.2810440873342875
# size _scaffolds  20119
# mem score avg:  0.7464568919497993
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.477755017182131
# avg filtered scores  0.284819294162296
# size _scaffolds  20234
# mem score avg:  0.7467738699328156
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.441592947368421
# avg filtered scores  0.30107555533228825
# size _scaffolds  20346
# mem score avg:  0.7468130278300764
# size mem:  200
# --- 1380 ---
# ---
# uniq valid count:  95
# avg pkx:  7.583673666666665
# avg filtered scores  0.3348187897641163
# size _scaffolds  20462
# mem score avg:  0.7468250994766791
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.506424706180345
# avg filtered scores  0.3003193787284806
# size _scaffolds  20560
# mem score avg:  0.7467703614697437
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.571215684210526
# avg filtered scores  0.3144916120573498
# size _scaffolds  20685
# mem score avg:  0.7469058559444889
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.46769196108551
# avg filtered scores  0.31117185811265197
# size _scaffolds  20794
# mem score avg:  0.7467730222788056
# size mem:  200
# --- 1400 ---
# ---
# uniq valid count:  92
# avg pkx:  7.459791813319529
# avg filtered scores  0.2970742379956637
# size _scaffolds  20905
# mem score avg:  0.7470971026219526
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.433066309523811
# avg filtered scores  0.3115606454118978
# size _scaffolds  21017
# mem score avg:  0.7472077732712102
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.291440949820789
# avg filtered scores  0.2844259072106447
# size _scaffolds  21118
# mem score avg:  0.7468495720370619
# size mem:  200
# --- 1420 ---
# ---
# uniq valid count:  98
# avg pkx:  7.499316350826046
# avg filtered scores  0.3210227996277494
# size _scaffolds  21224
# mem score avg:  0.7469722548841793
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.4514167921146965
# avg filtered scores  0.31527798316944144
# size _scaffolds  21329
# mem score avg:  0.7470772757334104
# size mem:  200
# ---
# uniq valid count:  98
# avg pkx:  7.509216737123422
# avg filtered scores  0.33304308958623946
# size _scaffolds  21451
# mem score avg:  0.7471375662524065
# size mem:  200
# --- 1440 ---
# ---
# uniq valid count:  95
# avg pkx:  7.636767280701755
# avg filtered scores  0.322756712807663
# size _scaffolds  21581
# mem score avg:  0.7473741752994312
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.5160665002560165
# avg filtered scores  0.31438497820339667
# size _scaffolds  21674
# mem score avg:  0.7476941114867564
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.423850620567376
# avg filtered scores  0.27944275870734475
# size _scaffolds  21795
# mem score avg:  0.7477115717658277
# size mem:  199
# ---
# uniq valid count:  93
# avg pkx:  7.439955967741936
# avg filtered scores  0.29583091720558913
# size _scaffolds  21888
# mem score avg:  0.7476585611691788
# size mem:  200
# --- 1460 ---
# ---
# uniq valid count:  97
# avg pkx:  7.340943917525774
# avg filtered scores  0.2605906325464003
# size _scaffolds  22001
# mem score avg:  0.7483433798707168
# size mem:  200
# ---
# uniq valid count:  97
# avg pkx:  7.801201757486502
# avg filtered scores  0.36096196470594183
# size _scaffolds  22125
# mem score avg:  0.7483928913966339
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.1703778320802005
# avg filtered scores  0.23207464384732873
# size _scaffolds  22226
# mem score avg:  0.7484341035644231
# size mem:  200
# --- 1480 ---
# ---
# uniq valid count:  92
# avg pkx:  7.476029420289855
# avg filtered scores  0.28796175389376943
# size _scaffolds  22326
# mem score avg:  0.7482702338761159
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.531248903654484
# avg filtered scores  0.3418504494586406
# size _scaffolds  22432
# mem score avg:  0.7485392619555451
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.6649492105263155
# avg filtered scores  0.32650453080536107
# size _scaffolds  22560
# mem score avg:  0.7486020946026137
# size mem:  199
# --- 1500 ---
# ---
# uniq valid count:  93
# avg pkx:  7.4623867690732215
# avg filtered scores  0.33085628322510124
# size _scaffolds  22688
# mem score avg:  0.7488089806879408
# size mem:  200
# ---
# uniq valid count:  95
# avg pkx:  7.547976526315789
# avg filtered scores  0.3330824401783251
# size _scaffolds  22805
# mem score avg:  0.7491818924730699
# size mem:  200
# ---
# uniq valid count:  94
# avg pkx:  7.600341914893618
# avg filtered scores  0.35839430885209933
# size _scaffolds  22920
# mem score avg:  0.7492105938581787
# size mem:  200
# ---
# uniq valid count:  93
# avg pkx:  7.355872532002048
# avg filtered scores  0.27785698396953395
# size _scaffolds  23015
# mem score avg:  0.749585210684668
# size mem:  200
# --- 1520 ---
# ---
# uniq valid count:  91
# avg pkx:  7.409869659863944
# avg filtered scores  0.30756962252351316
# size _scaffolds  23115
# mem score avg:  0.7495773037547742
# size mem:  200
# ---
# uniq valid count:  90
# avg pkx:  7.614066370370372
# avg filtered scores  0.3133940747371498
# size _scaffolds  23220
# mem score avg:  0.7498432410367729
# size mem:  200
# ---
# uniq valid count:  90
# avg pkx:  7.469316574074075
# avg filtered scores  0.28840704833969416
# size _scaffolds  23329
# mem score avg:  0.7498650679253877
# size mem:  200
# --- 1540 ---
# ---
# uniq valid count:  93
# avg pkx:  7.415896492575526
# avg filtered scores  0.2941193131106493
# size _scaffolds  23416
# mem score avg:  0.7498745261232932
# size mem:  200
# ---
# uniq valid count:  88
# avg pkx:  7.5614965909090905
# avg filtered scores  0.3473911380169246
# size _scaffolds  23522
# mem score avg:  0.7498745261232932
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.659174812734083
# avg filtered scores  0.35669794076892264
# size _scaffolds  23614
# mem score avg:  0.7500894648928502
# size mem:  200
# --- 1560 ---
# ---
# uniq valid count:  89
# avg pkx:  7.466572009095773
# avg filtered scores  0.3219592378900506
# size _scaffolds  23725
# mem score avg:  0.7501182466911561
# size mem:  200
# ---
# uniq valid count:  85
# avg pkx:  7.696666901960786
# avg filtered scores  0.37087383058876217
# size _scaffolds  23835
# mem score avg:  0.7503818900688506
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.503535205992509
# avg filtered scores  0.32120559732463294
# size _scaffolds  23953
# mem score avg:  0.7509157525947134
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.403108194905869
# avg filtered scores  0.30741681703502693
# size _scaffolds  24058
# mem score avg:  0.7507678076468555
# size mem:  200
# --- 1580 ---
# ---
# uniq valid count:  85
# avg pkx:  7.5556642941176495
# avg filtered scores  0.3415607441329895
# size _scaffolds  24145
# mem score avg:  0.7510186322688663
# size mem:  200
# ---
# uniq valid count:  88
# avg pkx:  7.367132576987405
# avg filtered scores  0.2620082298425931
# size _scaffolds  24241
# mem score avg:  0.7509996703268594
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.614585325670499
# avg filtered scores  0.32173725986483565
# size _scaffolds  24354
# mem score avg:  0.7509996703268594
# size mem:  200
# --- 1600 ---
# ---
# uniq valid count:  87
# avg pkx:  7.417632796934867
# avg filtered scores  0.30311513381685296
# size _scaffolds  24478
# mem score avg:  0.7513018637536959
# size mem:  200
# ---
# uniq valid count:  78
# avg pkx:  7.422240576923078
# avg filtered scores  0.3011971401810884
# size _scaffolds  24572
# mem score avg:  0.7516974410746485
# size mem:  200
# ---
# uniq valid count:  79
# avg pkx:  7.804366570223026
# avg filtered scores  0.39306473584746077
# size _scaffolds  24666
# mem score avg:  0.7519569640876407
# size mem:  200
# --- 1620 ---
# ---
# uniq valid count:  90
# avg pkx:  7.596656944444446
# avg filtered scores  0.35182167090306027
# size _scaffolds  24765
# mem score avg:  0.7520505988613516
# size mem:  200
# ---
# uniq valid count:  91
# avg pkx:  7.629143937728938
# avg filtered scores  0.3285941852260172
# size _scaffolds  24859
# mem score avg:  0.7520505988613516
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.585251104651163
# avg filtered scores  0.3330359132569057
# size _scaffolds  24961
# mem score avg:  0.7520570621449686
# size mem:  200
# ---
# uniq valid count:  85
# avg pkx:  7.748330098039216
# avg filtered scores  0.37717200555551667
# size _scaffolds  25063
# mem score avg:  0.7520620436890388
# size mem:  200
# --- 1640 ---
# ---
# uniq valid count:  88
# avg pkx:  7.42820571969697
# avg filtered scores  0.29834480833891125
# size _scaffolds  25160
# mem score avg:  0.7522332720846326
# size mem:  200
# ---
# uniq valid count:  82
# avg pkx:  7.435947439024389
# avg filtered scores  0.3162015137040092
# size _scaffolds  25262
# mem score avg:  0.7522332720846326
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.372102170542633
# avg filtered scores  0.2671467865039239
# size _scaffolds  25362
# mem score avg:  0.7522401473901911
# size mem:  200
# --- 1660 ---
# ---
# uniq valid count:  83
# avg pkx:  7.714789406196216
# avg filtered scores  0.3458754195093933
# size _scaffolds  25471
# mem score avg:  0.752489270481479
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.7428609057971025
# avg filtered scores  0.36359620087176325
# size _scaffolds  25590
# mem score avg:  0.752489270481479
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.679648876404497
# avg filtered scores  0.34139266627287707
# size _scaffolds  25688
# mem score avg:  0.752494824951667
# size mem:  200
# --- 1680 ---
# ---
# uniq valid count:  92
# avg pkx:  7.681664606625259
# avg filtered scores  0.3541966617101177
# size _scaffolds  25804
# mem score avg:  0.7525856620221579
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.553676126270731
# avg filtered scores  0.3383254936138632
# size _scaffolds  25927
# mem score avg:  0.7533111353551374
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.815253740310078
# avg filtered scores  0.3833284069055622
# size _scaffolds  26046
# mem score avg:  0.7536568901884909
# size mem:  200
# ---
# uniq valid count:  86
# avg pkx:  7.613088622646732
# avg filtered scores  0.32572009228435456
# size _scaffolds  26155
# mem score avg:  0.7539184205173709
# size mem:  200
# --- 1700 ---
# ---
# uniq valid count:  83
# avg pkx:  7.504860341365462
# avg filtered scores  0.30969717822875975
# size _scaffolds  26266
# mem score avg:  0.7539892733028344
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.605004061302683
# avg filtered scores  0.3365756682065071
# size _scaffolds  26380
# mem score avg:  0.7541462975085179
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.5705961302682
# avg filtered scores  0.3190640586469104
# size _scaffolds  26482
# mem score avg:  0.7543362442437607
# size mem:  199
# --- 1720 ---
# ---
# uniq valid count:  90
# avg pkx:  7.636348129629631
# avg filtered scores  0.36733358713362807
# size _scaffolds  26586
# mem score avg:  0.7541846444036713
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.650751001642038
# avg filtered scores  0.3401327131833207
# size _scaffolds  26678
# mem score avg:  0.7544282963450171
# size mem:  200
# ---
# uniq valid count:  82
# avg pkx:  7.507443089430895
# avg filtered scores  0.32819634985779106
# size _scaffolds  26777
# mem score avg:  0.7546451225889712
# size mem:  200
# --- 1740 ---
# ---
# uniq valid count:  81
# avg pkx:  7.835186296296297
# avg filtered scores  0.3737409132626795
# size _scaffolds  26867
# mem score avg:  0.754693684644243
# size mem:  200
# ---
# uniq valid count:  83
# avg pkx:  7.575530020080322
# avg filtered scores  0.3571217763938866
# size _scaffolds  26973
# mem score avg:  0.7546680500992291
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.640322318007667
# avg filtered scores  0.3521154988803618
# size _scaffolds  27072
# mem score avg:  0.7546680500992291
# size mem:  200
# ---
# uniq valid count:  87
# avg pkx:  7.62274990421456
# avg filtered scores  0.3474895068567709
# size _scaffolds  27170
# mem score avg:  0.7545500079683564
# size mem:  200
# --- 1760 ---
# ---
# uniq valid count:  82
# avg pkx:  7.428860618466899
# avg filtered scores  0.3161844712447383
# size _scaffolds  27282
# mem score avg:  0.7546042928810951
# size mem:  200
# ---
# uniq valid count:  85
# avg pkx:  7.6222993529411776
# avg filtered scores  0.32816725258077756
# size _scaffolds  27383
# mem score avg:  0.7546042928810951
# size mem:  200
# ---
# uniq valid count:  83
# avg pkx:  7.775257013769364
# avg filtered scores  0.3864359598162962
# size _scaffolds  27491
# mem score avg:  0.7547743666930886
# size mem:  200
# --- 1780 ---
# ---
# uniq valid count:  85
# avg pkx:  7.663313456582634
# avg filtered scores  0.3574928475046443
# size _scaffolds  27597
# mem score avg:  0.7548829642099762
# size mem:  200
# ---
# uniq valid count:  84
# avg pkx:  7.324049642857145
# avg filtered scores  0.2681694655742257
# size _scaffolds  27688
# mem score avg:  0.7551601640314732
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.67885147940075
# avg filtered scores  0.3546650152101352
# size _scaffolds  27794
# mem score avg:  0.7553686498746955
# size mem:  200
# --- 1800 ---
# ---
# uniq valid count:  70
# avg pkx:  7.6282526666666675
# avg filtered scores  0.3306282325887903
# size _scaffolds  27873
# mem score avg:  0.7554361516671142
# size mem:  200
# ---
# uniq valid count:  76
# avg pkx:  7.4849488377193
# avg filtered scores  0.29274129079454086
# size _scaffolds  27956
# mem score avg:  0.7556524430352684
# size mem:  200
# ---
# uniq valid count:  80
# avg pkx:  7.815815729166667
# avg filtered scores  0.3879811016868236
# size _scaffolds  28053
# mem score avg:  0.7559522868826727
# size mem:  200
# ---
# uniq valid count:  77
# avg pkx:  7.5261724318322365
# avg filtered scores  0.29955069729793554
# size _scaffolds  28138
# mem score avg:  0.7559654185975647
# size mem:  200
# --- 1820 ---
# ---
# uniq valid count:  73
# avg pkx:  7.772786278538813
# avg filtered scores  0.36496135942049607
# size _scaffolds  28241
# mem score avg:  0.7561940581346335
# size mem:  197
# ---
# uniq valid count:  79
# avg pkx:  7.49822467299578
# avg filtered scores  0.31769143352522977
# size _scaffolds  28340
# mem score avg:  0.7557445237366051
# size mem:  200
# ---
# uniq valid count:  92
# avg pkx:  7.44691695652174
# avg filtered scores  0.2812374717564796
# size _scaffolds  28432
# mem score avg:  0.7558009640793603
# size mem:  200
# --- 1840 ---
# ---
# uniq valid count:  86
# avg pkx:  7.625832936046512
# avg filtered scores  0.32698319865387976
# size _scaffolds  28525
# mem score avg:  0.755618024712634
# size mem:  200
# ---
# uniq valid count:  75
# avg pkx:  7.491142666666668
# avg filtered scores  0.3106575689115931
# size _scaffolds  28606
# mem score avg:  0.755618024712634
# size mem:  200
# ---
# uniq valid count:  85
# avg pkx:  7.646882941176469
# avg filtered scores  0.32320179436031493
# size _scaffolds  28701
# mem score avg:  0.7559668934577976
# size mem:  199
# --- 1860 ---
# ---
# uniq valid count:  85
# avg pkx:  7.660335333333332
# avg filtered scores  0.3595517545613804
# size _scaffolds  28790
# mem score avg:  0.7559586948490506
# size mem:  200
# ---
# uniq valid count:  89
# avg pkx:  7.77041647940075
# avg filtered scores  0.36774595348426437
# size _scaffolds  28888
# mem score avg:  0.7560034016219704
# size mem:  200
# ---
# uniq valid count:  80
# avg pkx:  7.540162083333334
# avg filtered scores  0.32299990474524376
# size _scaffolds  28994
# mem score avg:  0.7560896295254861
# size mem:  200
# ---
# uniq valid count:  83
# avg pkx:  7.468908864027539
# avg filtered scores  0.3115320038597083
# size _scaffolds  29098
# mem score avg:  0.7561021355508036
# size mem:  200
# --- 1880 ---
# ---
# uniq valid count:  78
# avg pkx:  7.548953133903136
# avg filtered scores  0.33695579351982974
# size _scaffolds  29204
# mem score avg:  0.7562669211956314
# size mem:  200
# ---
# uniq valid count:  71
# avg pkx:  7.852862018779343
# avg filtered scores  0.3904097483001766
# size _scaffolds  29316
# mem score avg:  0.7548588371022176
# size mem:  200
# ---
# uniq valid count:  83
# avg pkx:  7.52977464716007
# avg filtered scores  0.31899909974456275
# size _scaffolds  29412
# mem score avg:  0.7558188242748701
# size mem:  200
# --- 1900 ---
# ---
# uniq valid count:  85
# avg pkx:  7.716780635854341
# avg filtered scores  0.37264502897786855
# size _scaffolds  29524
# mem score avg:  0.7561385193455001
# size mem:  200
# ---
# uniq valid count:  78
# avg pkx:  7.508427793040294
# avg filtered scores  0.32556664014970405
# size _scaffolds  29619
# mem score avg:  0.7561385193455001
# size mem:  200
# ---
# uniq valid count:  83
# avg pkx:  7.452329905335627
# avg filtered scores  0.25775356463086946
# size _scaffolds  29710
# mem score avg:  0.7562972734004396
# size mem:  197
# --- 1920 ---
# ---
# uniq valid count:  87
# avg pkx:  7.680057883141763
# avg filtered scores  0.3757584304744381
# size _scaffolds  29814
# mem score avg:  0.7558062012532472
# size mem:  200
# ---
# uniq valid count:  77
# avg pkx:  7.546262442795302
# avg filtered scores  0.3194270542419033
# size _scaffolds  29918
# mem score avg:  0.7560384852742288
# size mem:  200
# ---
# uniq valid count:  77
# avg pkx:  7.623270930735933
# avg filtered scores  0.33824003326562346
# size _scaffolds  30009
# mem score avg:  0.7564658850065139
# size mem:  200
# ---
# uniq valid count:  73
# avg pkx:  7.630246270928463
# avg filtered scores  0.32398905988091187
# size _scaffolds  30080
# mem score avg:  0.7564768909298933
# size mem:  200
# --- 1940 ---
# ---
# uniq valid count:  79
# avg pkx:  7.569302814948767
# avg filtered scores  0.348227601946761
# size _scaffolds  30154
# mem score avg:  0.7566901269186908
# size mem:  200
# ---
# uniq valid count:  71
# avg pkx:  7.652797132796783
# avg filtered scores  0.37587879210471864
# size _scaffolds  30242
# mem score avg:  0.7567549938756118
# size mem:  200
# ---
# uniq valid count:  79
# avg pkx:  7.600826717902352
# avg filtered scores  0.3374862627286963
# size _scaffolds  30333
# mem score avg:  0.7568725057744541
# size mem:  200
# --- 1960 ---
# ---
# uniq valid count:  76
# avg pkx:  7.503516600877193
# avg filtered scores  0.3174292872337747
# size _scaffolds  30426
# mem score avg:  0.7568658997440031
# size mem:  200
# ---
# uniq valid count:  79
# avg pkx:  7.639702679324895
# avg filtered scores  0.3441564784501996
# size _scaffolds  30509
# mem score avg:  0.7572357251149684
# size mem:  200
# ---
# uniq valid count:  73
# avg pkx:  7.7016825799086766
# avg filtered scores  0.36401801758334085
# size _scaffolds  30608
# mem score avg:  0.7575560781172254
# size mem:  200
# --- 1980 ---
# ---
# uniq valid count:  68
# avg pkx:  7.596836299019608
# avg filtered scores  0.3509558760174903
# size _scaffolds  30685
# mem score avg:  0.7577862562737482
# size mem:  200
# ---
# uniq valid count:  77
# avg pkx:  7.6227810173160195
# avg filtered scores  0.35579662651184374
# size _scaffolds  30757
# mem score avg:  0.7579845303785042
# size mem:  200
# ---
# uniq valid count:  69
# avg pkx:  7.649679468599034
# avg filtered scores  0.32945303620645516
# size _scaffolds  30845
# mem score avg:  0.7581045559118961
# size mem:  200
# ---
# uniq valid count:  79
# avg pkx:  7.768483966244725
# avg filtered scores  0.37557111313266617
# size _scaffolds  30934
# mem score avg:  0.7581199107724137
# size mem:  200
# --- 2000 ---

# %% [markdown]
# Subsidiary files building for evaluation phase

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # use tensorflow cpu

import fcd
import pickle
from logics_pack import frechet_chemnet
fc_ref_model = fcd.load_ref_model()

config.vc_fmt = project_paths['PROJECT_DIR'] + 'model-kor/augmem/kor_augmem_vc_e%d.smi'  # save valid & canonical smiles
config.npfps_fmt = project_paths['PROJECT_DIR'] + 'model-kor/augmem/kor_augmem_npfps_e%d.npy'  # save fingerprint in npy
config.fcvec_fmt = project_paths['PROJECT_DIR'] + 'model-kor/augmem/kor_augmem_fcvec_e%d.npy'  # save Frechet ChemNet vectors

epochs = list(range(0, config.max_epoch+1, config.save_period))
np.array(epochs)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3313: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2023-07-06 10:16:44.188080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-07-06 10:16:44.223327: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-06 10:16:44.223359: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: shepherd5
# 2023-07-06 10:16:44.223367: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: shepherd5
# 2023-07-06 10:16:44.223451: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 465.19.1
# 2023-07-06 10:16:44.223483: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 465.19.1
# 2023-07-06 10:16:44.223490: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 465.19.1
# 2023-07-06 10:16:44.224420: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-07-06 10:16:44.241349: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299915000 Hz
# 2023-07-06 10:16:44.244995: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x9d13bd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-07-06 10:16:44.245018: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /home/bsbae402/anaconda3/envs/logics/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# array([   0,   20,   40,   60,   80,  100,  120,  140,  160,  180,  200,
#         220,  240,  260,  280,  300,  320,  340,  360,  380,  400,  420,
#         440,  460,  480,  500,  520,  540,  560,  580,  600,  620,  640,
#         660,  680,  700,  720,  740,  760,  780,  800,  820,  840,  860,
#         880,  900,  920,  940,  960,  980, 1000, 1020, 1040, 1060, 1080,
#        1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280, 1300,
#        1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520,
#        1540, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740,
#        1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960,
#        1980, 2000])

# %%
for epo in epochs:
    print(epo)
    with open(config.sample_fmt%epo, 'r') as f:
        gens = [line.strip() for line in f.readlines()]
    vcs, invids = chemistry.get_valid_canons(gens)
    print("- count invalids: ", len(invids))
    with open(config.vc_fmt%epo, 'w') as f:
        f.writelines([line+'\n' for line in vcs])
    fps = chemistry.get_fps_from_smilist(vcs)
    np.save(config.npfps_fmt%epo, chemistry.rdk2npfps(fps))
    fcvecs = fcd.get_predictions(fc_ref_model, vcs)  # ChemNet vectors
    np.save(config.fcvec_fmt%epo, fcvecs)
# Out:
# 0
# - count invalids:  952
# 20
# - count invalids:  1059
# 40
# - count invalids:  1009
# 60
# - count invalids:  1167
# 80
# - count invalids:  1195
# 100
# - count invalids:  1165
# 120
# - count invalids:  1165
# 140
# - count invalids:  1064
# 160
# - count invalids:  1079
# 180
# - count invalids:  986
# 200
# - count invalids:  831
# 220
# - count invalids:  890
# 240
# - count invalids:  905
# 260
# - count invalids:  785
# 280
# - count invalids:  776
# 300
# - count invalids:  849
# 320
# - count invalids:  781
# 340
# - count invalids:  817
# 360
# - count invalids:  802
# 380
# - count invalids:  788
# 400
# - count invalids:  755
# 420
# - count invalids:  681
# 440
# - count invalids:  690
# 460
# - count invalids:  619
# 480
# - count invalids:  635
# 500
# - count invalids:  642
# 520
# - count invalids:  584
# 540
# - count invalids:  561
# 560
# - count invalids:  525
# 580
# - count invalids:  570
# 600
# - count invalids:  522
# 620
# - count invalids:  500
# 640
# - count invalids:  583
# 660
# - count invalids:  550
# 680
# - count invalids:  547
# 700
# - count invalids:  535
# 720
# - count invalids:  608
# 740
# - count invalids:  511
# 760
# - count invalids:  527
# 780
# - count invalids:  508
# 800
# - count invalids:  493
# 820
# - count invalids:  545
# 840
# - count invalids:  482
# 860
# - count invalids:  506
# 880
# - count invalids:  466
# 900
# - count invalids:  466
# 920
# - count invalids:  492
# 940
# - count invalids:  514
# 960
# - count invalids:  490
# 980
# - count invalids:  510
# 1000
# - count invalids:  474
# 1020
# - count invalids:  478
# 1040
# - count invalids:  441
# 1060
# - count invalids:  417
# 1080
# - count invalids:  430
# 1100
# - count invalids:  437
# 1120
# - count invalids:  403
# 1140
# - count invalids:  375
# 1160
# - count invalids:  386
# 1180
# - count invalids:  389
# 1200
# - count invalids:  404
# 1220
# - count invalids:  394
# 1240
# - count invalids:  404
# 1260
# - count invalids:  374
# 1280
# - count invalids:  391
# 1300
# - count invalids:  356
# 1320
# - count invalids:  379
# 1340
# - count invalids:  376
# 1360
# - count invalids:  363
# 1380
# - count invalids:  400
# 1400
# - count invalids:  328
# 1420
# - count invalids:  342
# 1440
# - count invalids:  307
# 1460
# - count invalids:  364
# 1480
# - count invalids:  326
# 1500
# - count invalids:  365
# 1520
# - count invalids:  387
# 1540
# - count invalids:  319
# 1560
# - count invalids:  295
# 1580
# - count invalids:  331
# 1600
# - count invalids:  257
# 1620
# - count invalids:  304
# 1640
# - count invalids:  312
# 1660
# - count invalids:  330
# 1680
# - count invalids:  336
# 1700
# - count invalids:  311
# 1720
# - count invalids:  285
# 1740
# - count invalids:  310
# 1760
# - count invalids:  249
# 1780
# - count invalids:  303
# 1800
# - count invalids:  278
# 1820
# - count invalids:  216
# 1840
# - count invalids:  270
# 1860
# - count invalids:  236
# 1880
# - count invalids:  299
# 1900
# - count invalids:  293
# 1920
# - count invalids:  300
# 1940
# - count invalids:  274
# 1960
# - count invalids:  239
# 1980
# - count invalids:  282
# 2000
# - count invalids:  217

# %% [markdown]
# Evaluate FCD and OTD on validation set, and pick the best epoch

# %%
# which validation fold recorded
vfold = expset_obj.get_setting("kor-pred-best-cv")
vfold
# Out:
# '3'

# %%
affinity_data = pd.read_csv(project_paths['KOR_DATA_PATH'])

# data split info
with open(project_paths['KOR_FOLD_JSON'], 'r') as f:
    kor_folds = json.load(f)

# retrieve validation set
val_ids = kor_folds[vfold]
val_data = affinity_data.iloc[val_ids]

# get validation set activate (vsa)
vsa_data = val_data[val_data['affinity']>global_settings.KOR_ACT_THRS]  # active among validation set
len(vsa_data)

vsa_smis = vsa_data['smiles'].tolist()
vsa_rdkfps = chemistry.get_fps_from_smilist(vsa_smis)
vsa_fc_vecs = fcd.get_predictions(fc_ref_model, vsa_smis)

dsize = len(vsa_rdkfps)  # demand size for OT
ssize = dsize*global_settings.OT_CALC_REPEATS  # supply size for repeated OT

# load predictor for PredAct (avg. predicted activity) calculation
with open(config.predictor_path, 'rb') as f:
    predictor = pickle.load(f)

# %%
val_fcd_list = []
val_otd_list = []
predact_list = []

for epo in epochs:
    print(epo)
    # load fc vectors of generation
    gen_fcvecs = np.load(config.fcvec_fmt%epo)
    fcdval = frechet_chemnet.fcd_calculation(gen_fcvecs, vsa_fc_vecs)
    val_fcd_list.append(fcdval)
    
    gen_npfps = np.load(config.npfps_fmt%epo)[:ssize]  # only need this amount
    gen_rdkfps = chemistry.np2rdkfps(gen_npfps)
    simmat = analysis.calculate_simmat(gen_rdkfps, vsa_rdkfps)  # row:gen, col:data
    distmat = analysis.transport_distmat(analysis.tansim_to_dist, simmat, global_settings.OT_CALC_REPEATS)
    _, _, motds = analysis.repeated_optimal_transport(distmat, repeat=global_settings.OT_CALC_REPEATS)
    val_otd_list.append(np.mean(motds))

    # record PredAct
    predact_list.append(np.mean(predictor.predict(gen_npfps)))
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000

# %%
# validation FCDxOTD
val_FCDxOTD = np.array(val_fcd_list)*np.array(val_otd_list)
# dataframe for validation performance
v_perf = pd.DataFrame(epochs, columns=['epoch'])
v_perf['v-OTDxFCD'] = val_FCDxOTD
v_perf['v-OTD'] = val_otd_list
v_perf['v-FCD'] = val_fcd_list
v_perf['PredAct'] = predact_list
v_perf
# Out:
#      epoch   v-OTDxFCD     v-OTD      v-FCD   PredAct
# 0        0  151.870015  5.373718  28.261627  5.950143
# 1       20  134.184715  5.291485  25.358612  6.152877
# 2       40  124.779109  5.247167  23.780282  6.208436
# 3       60  123.527241  5.246429  23.545012  6.243472
# 4       80  124.012755  5.281934  23.478665  6.283508
# ..     ...         ...       ...        ...       ...
# 96    1920  193.126009  5.591267  34.540654  7.698707
# 97    1940  209.781165  5.772098  36.344008  7.690865
# 98    1960  205.133997  5.735355  35.766572  7.694452
# 99    1980  208.908194  5.825910  35.858467  7.702056
# 100   2000  213.281347  5.841961  36.508520  7.713498
#
# [101 rows x 5 columns]

# %%
# we are only interested in epochs that achieved PredAct > (activity threshold)
subv = v_perf[v_perf['PredAct']>global_settings.KOR_ACT_THRS].copy()

# find the best epoch
vbest = subv.loc[subv['v-OTDxFCD'].idxmin()]
print(vbest)

# register the best epoch
expset_obj.update_setting('kor-augmem-best-epoch', int(vbest['epoch']))
# Out:
# epoch        400.000000
# v-OTDxFCD    143.180629
# v-OTD          5.285925
# v-FCD         27.087145
# PredAct        7.002252
# Name: 20, dtype: float64
